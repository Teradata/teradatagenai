# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Getting Started with Content-Based Vector Store on AI-FACTORY.
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Introduction</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Vector stores are specialized databases designed for efficient storage, indexing, and searching of high-dimensional vector embeddings. These embeddings, generated by AI models, enable similarity search and power applications in machine learning, NLP, recommendation systems, and image/video retrieval.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook provides an in-depth exploration of vector stores in the Teradata Database, covering key concepts, vector embedding mechanisms, and efficient search techniques.
# </p>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Key Concepts</b></p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>What is a Vector Store?</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# A vector store contains a vectorized representation of data, typically created using embeddings from AI models. It allows for high-speed similarity searches beyond traditional keyword matching.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Vector embeddings are numerical representations of data (text, images, audio, etc.) mapped into a multi-dimensional space.
# </p>
#
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Each embedding is a vector that captures semantic or content-based relationships. For example:
# </p>
#
# <table style="font-size:16px;font-family:Arial;color:#00233C;border:1px solid black;">
#   <tr>
#     <th style="border:1px solid black;padding:5px;">Data Type</th>
#     <th style="border:1px solid black;padding:5px;">Example</th>
#     <th style="border:1px solid black;padding:5px;">Vector Representation</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Text</td>
#     <td style="border:1px solid black;padding:5px;">"King"</td>
#     <td style="border:1px solid black;padding:5px;">[0.12, 0.45, 0.67, ...]</td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Image</td>
#     <td style="border:1px solid black;padding:5px;">A picture of a cat</td>
#     <td style="border:1px solid black;padding:5px;">[0.23, 0.78, 0.55, ...]</td>
#   </tr>
# </table>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# <b>Embedding Generation is carried out by AI_TextEmbedding Function </b>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Enables text embedding generation using LLMs hosted by Nim.</b> (Performs a full-table scan)</li>
#     <li> Accepts different parameters, model endpoint, key, model args etc.</li>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Vector Search</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Unlike traditional search methods, vector search understands the meaning behind a query. It provides relevant results by analyzing semantic relationships rather than exact keyword matches.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Common types of embeddings include:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
# <li>Word Embeddings</li>
# <li>Sentence Embeddings</li>
# <li>Document Embeddings</li>
# <li>Image Embeddings</li>
# <li>Audio Embeddings</li>
# </ul>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Vector Store in the Teradata Database</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# A vector in Teradata is a specialized column type called <b>Vector</b>.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The <b>vector store</b> in Teradata consists of schemas and tables that enable vector search functionality.
# </p>
#
# <hr>
#
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>Vector Search Algorithms</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Teradata supports three main search algorithms:
# </p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>1. VectorDistance</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>Flat index</b> (performs a full-table scan)</li>
#   <li><b>Scalable and parallel search</b></li>
#   <li><b>Exact search approach</b></li>
#   <li>Suitable for <b>smaller datasets (<10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>2. Kmeans</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>IVF (Inverted Vector File) index</b> (organizes data into clusters)</li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>3. HNSW</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>HNSW (Hierarchical Navigable Small World) index</b></li>
#   <li><b>Graph-based Approximate Nearest Neighbors (ANN) search</b></li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <hr>
#
#
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>Types of Vector Store</b></p>
#
# <table style="font-size:15px; font-family:Arial; color:#00233C; width:100%; border:1px solid #ddd; border-collapse:collapse;">
#   <tr>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Type</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Description</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Use Case</th>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>1. Content-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>contents of a table</b> (or file/PDF converted to a table). Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>2. Metadata-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>metadata</b> of tables. Queries return the <b>top matching tables</b> based on similarity. Used in <b>SQL generation</b> for data retrieval.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Helps form textual responses by retrieving data from relevant tables for more precise answers.</td>
#   </tr>
#     <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>3. File-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built from contents of PDF file. Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#     <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>4. Embedding-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built from the <b>user generated embeddings</b> . Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
# </table>
#
#
# </ul>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>What You Will Do in This Notebook</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# This notebook is designed to guide you through a comprehensive set of exercises focused on working with content-based Vector Store and ask APIs. By the end of this tutorial, you will have gained hands-on experience with creating content-based vector store objects as well as asking questions and performing similarity searches. Here's what you'll learn:
# </p>
#
# <div style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <ol>
# <li>
# <b>Installing latest teradatagenai</b>
# </li>
# <li>
# <b>Creating a new Content-Based Vector Store</b>
# </li>
# <li>
# <b>Using existing Vector Store</b>
# </li>
# <li>
# <b>Updating Vector Store</b>
# </li>
# <li>
# <b>Performing Similarity Seach and Asking questions</b>
# </li>
# <li>
# <b>Destroying Vector Store</b>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Installing latest teradatagenai</b>

# %%
# %pip install teradatagenai

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Import necessary modules</b>

# %%
import os
from getpass import getpass
# Required imports
from teradatagenai import VSManager, VectorStore, VSPattern, VSApi, TeradataAI, TextAnalyticsAI, load_data, ModelUrlParams
from teradataml import create_context, set_auth_token, DataFrame, in_schema, remove_context

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Connect to Vantage</b>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the details to create the connection to Vantage. Enter the details, press the Enter key, then use down arrow to go to next cell. Begin running steps with Shift + Enter keys.</p>

# %%
os.environ['TD_HOST'] = getpass(prompt='hostname: ')
os.environ['TD_USERNAME'] = getpass(prompt='username: ')
os.environ['TD_PASSWORD'] = getpass(prompt='password: ')
os.environ['TD_BASE_URL'] = getpass(prompt='base_url: ')
os.environ['TD_AUTH_MECH'] = getpass(prompt='auth_mech: ')
context = create_context()
# Out:
# Authentication token is generated and set for the session.
# Engine(teradatasql://vsdemo01:***@10.27.178.11)

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>1. Getting Started with Vector Store </b>

# %% [markdown]
# ### 🛠 Steps to Create a Vector Store
#
# 1. **Initialize a VectorStore Instance**
#    - Create an instance of `VectorStore`
#
# 2. **Create the Vector Store**
#    - Use the `create()` method on the vector store instance to create a new vector store.
#
# **Note: embeddings_base_url refers to NVIDIA NIM deployment endpoint and ingest_host refers to NV-INGEST service.**
#
# By following these steps, we will successfully create vector store - `aionprem`.

# %% [markdown]
# **NOTE:**
# - To generate the endpoint URLs for the embedding and chat completion models, please refer to the **GetNimEndpoints** notebook.
# - The notebook walks through the steps required to get the urls for the `embeddings_base_url` and `completions_base_url` parameters when creating your Vector Store.

# %%
embeddings_url = getpass(prompt='embeddings_base_url: ')
completions_url = getpass(prompt='completions_base_url: ')

# %%
vs = VectorStore(name="aionprem1")

# %%
vs.destroy()
# Out:
# Vector store aionprem1 destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
# Create an input DataFrame.
input_data = DataFrame('amazon_reviews_25')

# %%
vs.create(embeddings_model= 'nvidia/llama-3.2-nv-embedqa-1b-v2',
          chat_completion_model='mistralai/mistral-7b-instruct-v0.3',
          chat_completion_max_tokens=8192,
          embeddings_dims=2048,
          search_algorithm= 'VECTORDISTANCE',
          top_k=10,
          object_names= input_data,
          key_columns= ['rev_id', 'aid'],
          data_columns= ['rev_text'],
          metadata_columns= ['prodsummary', 'rev_name'],
          use_simd = True,
          embeddings_base_url=embeddings_url,
          completions_base_url=completions_url,
          )
# Out:
# Vector store aionprem1 creation started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### ✅ Checking the Status of the Vector Store
#
# Though the create, update, destroy APIs are synchronous and will complete only after the operation is complete, user can ensure the same using the **status** API.
#
#  **Check the `status`**
#    - The `status` function allows you to confirm whether the particular operation is successful.

# %% [markdown]
# #### In this example, we can see the status of creation using **status()**

# %%
vs.status()
# Out:
#      vs_name status
# 0  aionprem1  READY

# %% [markdown]
# ### Check the type of vector store using `store_type` parameter.

# %%
vs.store_type
# Out:
# 'content-based'

# %% [markdown]
# #### Get the details of the Vector Store.

# %%
vs.get_details()
# Out:
#      vs_name     store_type description database_name  sample_size                   embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold search_numcluster ef_search initial_centroids_method train_numcluster max_iternum stop_threshold  seed num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects                    document_objects document_columns   document_indexes prompt vector_column               chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status                                                                                base_url_embeddings                                                                     base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated                                                                       metadata_columns base_url_content_safety base_url_topic_control base_url_jailbreak_detection content_safety_model topic_control_model guardrails num_NodesPerGraph onnx_model_table onnx_tokenizer_table onnx_model_id onnx_tokenizer_id onnx_model_column onnx_tokenizer_column onnx_model_id_column onnx_tokenizer_id_column embedding_datatype  use_simd base_url_vlm vlm_model  maximal_marginal_relevance  lambda_multiplier permission
# 0  aionprem1  content-based        None      VSDEMO01           20  nvidia/llama-3.2-nv-embedqa-1b-v2             2048  COSINE   VECTORDISTANCE     10             None              None      None                     None             None        None           None  None     None      None            None            None               None             None             None             None            None            None  ["\"VSDEMO01\".amazon_reviews_25"]     ["rev_text"]  ["rev_id", "aid"]   None  vector_index  mistralai/mistral-7b-instruct-v0.3            0.2                       None               60                        8192     READY  https://gpudev1-modelops.labs.teradata.com/serving/nvidia-llama-32-nv-embedqa-1b-v2/v1/embeddings  https://gpudev1-modelops.labs.teradata.com/serving/mistralai-mistral-7b-instruct-v03/v1            None             None          None            None       None             None               None        None          None                None  2025-10-21 12:02:07.942831+00:00  [{"name": "prodsummary", "description": ""}, {"name": "rev_name", "description": ""}]                    None                   None                         None                 None                None       None              None             None                 None          None              None              None                  None                 None                     None           VECTOR32         1         None      None                           0                0.5      ADMIN

# %% [markdown]
# #### Use the get_indexes_embeddings function to get the vector store which is created internally.

# %%
output = vs.get_indexes_embeddings()

# %%
output.head(1)
# Out:
#   DataBaseName          TableName         rev_id         aid      prodsummary rev_name                                                                                                                                                                                                                                       rev_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      vector_index                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           vector_index_normalized
# 0     VSDEMO01  amazon_reviews_25  A5E9TSD20U9PR  000100039X  Just beautiful.    April  For those who don"t know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions. This is a relationship with a man"s work you won"t regret having.          21  0.00373300001956522,-0.0358580015599728,-0.0149229997768998,-0.0120930001139641,-0.044463999569416,0.00715600000694394,0.0195620004087687,-0.0138170002028346,-0.00879700016230345,-0.00591300008818507,0.0131989996880293,0.000989999971352518,-0.00794200040400028,-0.0296480003744364,0.0133969997987151,-0.0128020001575351,-0.0440060012042522,0.0045779999345541,0.0196690000593662,-0.020966000854969,-0.0202329996973276,0.0252989996224642,-0.0158229991793633,0.00859799981117249,0.0194850005209446,-0.0196230001747608,0.0582580007612705,0.00136200000997633,0.00503200013190508,0.010673999786377,-0.0271300002932549,-0.0238799992948771,-0.00114199996460229,0.00084900000365451,0.00666800001636147,-0.00318300002254546,0.0156859997659922,-0.0328980013728142,-0.00749599980190396,0.00842299964278936,0.0215910002589226,-0.036591000854969,-0.00520299980416894,0.0391849987208843,0.00430699996650219,0.0350949987769127,-0.0206300001591444,-0.0380249992012978,0.0123899998143315,0.0170290004462004,0.0241550002247095,-0.0145490001887  0.00373296649195254,-0.0358576774597168,-0.0149228656664491,-0.0120928911492229,-0.0444636009633541,0.00715593574568629,0.0195618234574795,-0.0138168754056096,-0.00879692099988461,-0.00591294700279832,0.0131988804787397,0.000989991007372737,-0.00794192869216204,-0.02964773401618,0.013396879658103,-0.0128018846735358,-0.0440056063234806,0.00457795895636082,0.019668823108077,-0.020965812727809,-0.020232817158103,0.025298772379756,-0.0158228576183319,0.00859792251139879,0.0194848254323006,-0.0196228232234716,0.0582574754953384,0.00136198778636754,0.00503195496276021,0.0106739038601518,-0.0271297562867403,-0.0238797850906849,-0.00114198972005397,0.00084899237845093,0.00666793994605541,-0.00318297138437629,0.0156858582049608,-0.0328977070748806,-0.0074959322810173,0.00842292420566082,0.0215908065438271,-0.0365906730294228,-0.00520295277237892,0.039184644818306,0.00430696131661534,0.0350946821272373,-0.0206298138946295,-0.0380246564745903,0.0123898880556226,0.0170288477092981,0.0241547822952271,-0.0145488688722253,

# %% [markdown]
# #### Use the `list` function to retrieve all available vector stores and confirm if `aionprem` has been created.

# %%
VSManager.list()
# Out:
#                                     vs_name       store_type                                                                                                                                                                      description database_name      vs_status permission
# 0                               embedded_df  embedding-based                                                                                                                                                                             None      VSDEMO01          READY      ADMIN
# 1                      TD_UDF_ORANGE_BOOK_2  embedding-based                                                                                                                                                         Teradata UDF Orange Book          doug          READY  NO ACCESS
# 2                            my_embed_vs_12  embedding-based                                                                                                                                                                             None     demo_user          READY  NO ACCESS
# 3             e2e_test_402b890b_update_test  embedding-based                                                                                                                                                           nv_ingest_vector_store      VSDEMO01          READY      ADMIN
# 4                         cricket_vs_pdf_42  embedding-based                                                                                                                                                                             None     demo_user  CREATE FAILED  NO ACCESS
# 5                      error_logs_critical1  embedding-based  this vector store include all the critical issues of error log information, you can find the similar error log here and the associated jira number and root cause and solution      test_user          READY  NO ACCESS
# 6  test_vector_store_update_params_b7933146       file-based                                                                                                                                                                             None      vsdemo01  CREATE FAILED      ADMIN
# 7                             vs_test_model    content-based                                                                                                                                                                             None      VSDEMO01          READY      ADMIN
# 8                       vs_teradata_tier_10  embedding-based                                                                                                                                                           nv_ingest_vector_store      VSDEMO01          READY      ADMIN
# 9                               ball_basket  embedding-based                                                                                                                                                     basketball game related info     demo_user          READY  NO ACCESS

# %% [markdown]
# ### 🔍 Performing Similarity Search.
#
# \**similarity search** allows us to find the most relevant vectors based on a given input. By passing a question to the vector store `aionprem`, we can retrieve the closest matches based on the selected search algorithm.
#
# #### 🛠 How It Works
#
# 1. **Input a question**
#    - Pass a question or input text to `question` argument of `similarity_search()`.
#
# 2. **Perform the Similarity Search**
#    - The vector store searches for the most relevant matches using the specified **`search_algorithm`**.
#
# 3. **Retrieve Top Matches**
#    - The result contains the **top_k** most relevant entries along with their similarity scores, helping us understand how closely they match the input.
#
# This process enables efficient retrieval of information based on vector embeddings, making it useful for applications such as **semantic search, recommendation systems, and document retrieval**. 🚀

# %%
question = 'Which book are all the reviews talking about?'
response = vs.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                         prodsummary                                    rev_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    rev_text  index_label
# 0  0.699694     VSDEMO01  amazon_reviews_25  A2I35JB67U20C0  000100039X                      Everyone should have this book                             Amazon Customer  When I was in college in the 70"s this book had a revival and I did not read it then.  Recently a friend (who is 90) and I were talking about work and she said: &quot;work is love made visible,&quot; and told me it was from the Prophet.  I though that was so beautiful I got the book and was not disappointed.You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible.He says it WAY better that I do and says much more in just a few paragraphs.  But as you can see from the example, what he says is not religious, but positive ways of looking at things.  Since I rediscoverd the book I have given away many copies and everyone I have given it to sincerly thanked me.            2
# 1  0.671943     VSDEMO01  amazon_reviews_25  A12387207U8U24  000100039X                                          Graet Work                                        Alex                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              As you read, Gibran"s poetry brings spiritual and visual beauty to life within you. Gibran is justly famous for rich metaphors that brilliantly highlight the pursuit of Truth and Goodness amidst all the darkness and light of human nature.            4
# 2  0.670070     VSDEMO01  amazon_reviews_25  A1MOSTXNIO5MPJ  000100039X  Timeless for every good and bad time in your life.                                   Alan Krug                                                                             I first read THE PROPHET in college back in the 60"s. The book had a revival as did anything metaphysical in the turbulent 60"s. It had a profound effect on me and became a book I always took with me. After graduation I joined the Peace Corps and during stressful training in country (Liberia) at times of illness and the night before I left, this book gave me great comfort. I read it before I married, just before and again after my children were born and again after two near fatal illnesses. I am always amazed that there is a chapter that reaches out to you, grabs you and offers both comfort and hope for the future.Gibran offers timeless insights and love with each word. I think that we as a nation should read AND learn the lessons here. It is definitely a time for thought and reflection this book could guide us through.            5
# 3  0.667107     VSDEMO01  amazon_reviews_25  A2XQ5LZHTD4AFT  000100039X                                       A Modern Rumi                                    Alaturka                                                                                               A timeless classic.  It is a very demanding and assuming title, but Gibran backs it up with some excellent style and content.  If he had the means to publish it a century or two earlier, he could have inspired a new religion.From the mouth of an old man about to sail away to a far away destination, we hear the wisdom of life and all important aspects of it.  It is a messege.  A guide book.  A Sufi sermon. Much is put in perspective without any hint of a dogma.  There is much that hints at his birth place, Lebanon where many of the old prophets walked the Earth and where this book project first germinated most likely.Probably becuase it was written in English originally, the writing flows, it is pleasant to read, and the charcoal drawings of the author decorating the pages is a plus.  I loved the cover.            6
# 4  0.626891     VSDEMO01  amazon_reviews_25  A1KQ80Y692CDOI  000100039X                                            Eloquent                                       Atown                                                                                                                                                                                                     I read this about a year ago and can"t recall a great deal of the book. From what I do recall it was like a poem all the way through. While the writing was beautiful, I found it ambiguous and befuddled with meaning that I could not identify with. When Gibran speaks of God, I cannot identify because I have since abandoned those philosophies. It is thus difficult to revisit them in this book. I have the feeling a may have missed something great about this book. Indeed, I pulled wisdom from parts, but rather than go back and read it again, for now, perhaps I will move on to another of the many books out there that are enlightening and worth reading. Someday, I would like to read this again and dig deeper.            8
# 5  0.614990     VSDEMO01  amazon_reviews_25   A5E9TSD20U9PR  000100039X                                     Just beautiful.                                       April                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               For those who don"t know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions. This is a relationship with a man"s work you won"t regret having.            9
# 6  0.648460     VSDEMO01  amazon_reviews_25  A3V1MKC2BVWY48  000100039X                      This book will bring you peace                                 Alex Dawson                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Reading this made my mind feel like a still pool of water, cool and quiet in a mossy grotto.  It"s direct and simple wisdom has a depth of complexity that takes a quiet day to sink in, leaving you at peace.  It is best to set time aside for it, relax, absorb, and let it softly clear your mind.            7
# 7  0.674500     VSDEMO01  amazon_reviews_25  A2X4HE21JTAL98  000100039X                                            Flawless                                 Antiquarian                                                                                                                                                                                                                                                                                                                                                                                                                                       Anything I"ve read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran"s work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that. The poetic style, the aphorisms, the parables, the almost biblical feel, are all just what over-worked, over-stressed, modern and spiritually starved worldly people need.            3
# 8  0.708091     VSDEMO01  amazon_reviews_25  A19N3FCQCLJYUA  000100039X               A book everyone &#34;should&#34; read                             Amazon Customer                                      I discovered The Prophet fifty years ago in college and have read it dozens of times since then.  Now, in addition to my beat up hard copy, I have a portable e-copy.  If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it.  It doesn"t care how you picture, name or define &#34;God&#34; or whether you give him a gender and a personality.  It just cuts to the heart of how to live and how to relate to others.  If Jesus and the Buddha teamed up to write a book, it might come out like this.When I first read it, I found some passages difficult to grasp.  Looking back, I now think that it was not because they were hard to understand, but because I did not want to hear gently spoken, intelligently phrased ideas that contradicted my own.  Now, if I could have only one book, this would probably be it.            1
# 9  0.708325     VSDEMO01  amazon_reviews_25  A2LBBQHYLEHM7P  000100039X                                    A Modern Classic  "Amazon Customer ""Full Frontal Nerdity"""                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        An amazing work. Realizing extensive use of Biblical imagery and sentence structure, &#34;The Prophet&#34; by Khalil Gibran is a literary classic. Influencing the Free Love movement of the 1960"s, Gibran"s master work explores themes of love, longing and loss.            0

# %% [markdown]
# ### 📝 Generating a Natural Language Response
#
# Once the **`similarity_search()`** method retrieves relevant results from the vector store, we can generate a natural language response by proving a prompt..
#
# #### 🛠 Steps to Prepare the Response
# 1.  **Input a question**
#    - Pass a question or input text to `question` argument of `prepare_response()`.
#
# 1. **Retrieve Similarity Results**
#    - The `similarity_search()` method returns the most relevant matches along with their similarity scores.
#
# 3. **Input a prompt**
#    - By passing `prompt`, we ask the model to format the output in a particular way
#
# #### As we can see below, by passing the question and the prompt, the response is formated in a conversational manner as suggested in the prompt.

# %%
question='Did any one feel the book is thin?'
prompt='Format the response in a conversational way.'
response = vs.prepare_response(question=question, similarity_results=response, prompt=prompt)

# %%
print(response)
# Out:
# It seems that the book in question, "The Prophet" by Khalil Gibran, is not perceived as thin by many of the reviewers. Instead, they find it to be insightful, thought-provoking, and full of timeless wisdom. Some even describe it as a treasure, a masterpiece, and a guidebook for life. The language and delivery are praised for their familiar yet penetrating quality, and the book is appreciated for its ability to offer different insights with each reading. While the literary quality may not be exceptional, the message behind it is considered powerful and enlightening. So, it seems that the thickness of the book is not a concern for most readers, but rather the depth of its content that is valued.

# %% [markdown]
# ### ⚡ ask:
# #### Unified Similarity Search & Response Generation
# To improve efficiency, we can **combine similarity search and response generation** into a single operation. This method performs a similarity search in the vector store using the **input query** and then prepares a natural language response based on the retrieved results.
#
# #### 🔍 How It Works
#
# 1.  **Input a question**
#    - Pass a question or input text to `question` argument of `ask()`.
#
# 3. **Input a prompt**
#    - By passing `prompt`, we ask the model to format the output in a particular way
#
# **Faster Execution**
#    - By combining both steps into a single function call, response time is reduced, making the system more efficient.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
Review ID: 
Author ID: 
Review: 
"""
question ='Are there any reviews saying that the books are inspiring?'
response = vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are several reviews that mention the books as inspiring. Here are a few examples:
#
# 1. Review ID: 000100039X, Author ID: 000100039X, Review: "Anything I've read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran's work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that."
#
# 2. Review ID: 000100039X, Author ID: ARDQ9KNB8K22N, Review: "It is full of timeless truths which are of lasting value to the reader and inform life. The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a sermon by Jesus. I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter. Excellent for busy people or commuters!"
#
# 3. Review ID: 000100039X, Author ID: A2S166WSCFIFP5, Review: "It is a masterpiece of spirituality. I'll be the first to admit, its literary quality isn't much. It is rather simplistically written, but the message behind it is so powerful that you have to read it. It will take you to enlightenment."
#
# 4. Review ID: 000100039X, Author ID: A2XQ5LZHTD4AFT, Review: "A timeless classic. It is a very demanding and assuming title, but Gibran backs it up with some excellent style and content. If he had the means to publish it a century or two earlier, he could have inspired a new religion."
#
# 5. Review ID: 000100039X, Author ID: A19N3FCQCLJYUA, Review: "I discovered The Prophet fifty years ago in college and have read it dozens of times since then. Now, in addition to my beat up hard copy, I have a portable e-copy. If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it. It doesn't care how you picture, name or define 'God' or whether you give him a gender and a personality. It just cuts to the heart of how to live and how to relate to others. If Jesus and the Buddha teamed up to write a book, it might come out like this."
#
# 6. Review ID: 000100039X, Author ID: A5E9TSD20U9PR, Review: "For those who don't know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions. This is a relationship with a man's work you won't regret having."
#
# 7. Review ID: 000100039X, Author ID: A27ZH1AQORJ1L, Review: "This book is everything that is simple, delicate, true, and beautiful. I have read few books so touching and enlightening; 'The Prophet' is a true masterpiece that has that feeling of ancient wisdom in it. The wisdom of the text is gentle, yet insistent, it lets you understand things you've always known. My feelings defy description."

# %%
VSManager.disconnect()
# Out:
# Database connection closed.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
#
# <b style="font-size:30px; font-family:Arial; color:#00233C;">2. Initializing and Using the Existing Vector Store</b>

# %% [markdown]
# ### 🔄 Using an Existing Vector Store
#
# If you have an existing vector store that you want to reuse, you can initialize it by providing the **name** of the store. This allows you to interact with and perform operations on the existing store without creating a new one.
#
# #### 🛠 Steps to Initialize existing Vector Store
#
# 1. **Provide the Name of the Vector Store**
#    - Specify the name (e.g., `aionprem`) of the existing vector store that you want to access.
#
#
# 2. **Initialize the Vector Store Instance**
#    - By using the provided name, you can initialize the vector store instance and begin interacting with it.

# %%
# Initialize existing VS
updated_vs = VectorStore("aionprem1")
# Out:
# Vector store aionprem1 is initialized.

# %% [markdown]
# ### ✨ Updating Arguments of an Existing Vector Store
#
# You can **update** specific parameters of an existing vector store without having to recreate it. For instance, you may want to modify the **search algorithm** or other configuration settings to better suit your needs. This can be done using the `update()` API, which allows you to change the arguments of the vector store.
#
# #### 🛠 Steps to Update an Existing Vector Store
#
# 1. **Access the Existing Vector Store**
#    - First, ensure that the vector store (e.g., `vs_update`) is already initialized.
#
# 2. **Use the `update()` API**
#    - Call the `update()` method on the vector store instance and provide the new argument(s) you want to modify, such as the `search_algorithm`.

# %%
updated_vs.update(search_algorithm="KMEANS")
# Out:
# Vector store aionprem1 update started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
#      vs_name status
# 0  aionprem1  READY

# %% [markdown]
# ### ✨ Updating Data of an Existing Vector Store
#
# You can **add** or **delete** data in a Vector Store.
#
# #### 🛠 Steps to Update an Existing Vector Store
#
# 1. **Access the Existing Vector Store**
#    - First, ensure that the vector store (e.g., `vs_update`) is already initialized.
#
# 2. **Use the `update()` API**
#    - Call the `update()` method on the vector store instance and provide the new argument(s).

# %%
# Create a new table with the contents to add to the Vector Store. 
# Make sure this table has the columns which are used as key_columns and metadata_columns in existing Vector Store.
import pandas as pd
from teradataml import copy_to_sql
from teradatasqlalchemy import VARCHAR
df = {'prod_name': ['A1', 'A2', 'A3', 'A4'],
      'rev_id': ['100', '200', '300', '400'],
      'rev_text': ['Product is good', 'quality is bad', 'needs improvement', 'Bad quality'],
      'prodsummary': ['Good product', 'Bad quality product', 'Average product', 'Poor quality product'],
      'rev_name': ['Review1', 'Review2', 'Review3', 'Review4'],
      'aid': ['99.99', '97.32', '94.67', '91.00']
      }
pandas_df = pd.DataFrame(df)
copy_to_sql(df=pandas_df, table_name='test_table_update',
            if_exists='replace',
            types={'rev_text': VARCHAR(64000)})

# %%
updated_vs.update(object_names='test_table_update',
                  alter_operation="ADD",
                  update_style="MINOR")
# Out:
# Vector store aionprem1 update started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
#      vs_name status
# 0  aionprem1  READY

# %%
op = updated_vs.get_indexes_embeddings()

# %%
op.loc[op['TableName'] == 'test_table_update']
# Out:
#   DataBaseName          TableName rev_id    aid           prodsummary rev_name           rev_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      vector_index                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           vector_index_normalized
# 0     VSDEMO01  test_table_update    400  91.00  Poor quality product  Review4        Bad quality          28  -0.0209350008517504,0.0149769997224212,0.0315859988331795,0.00891899969428778,0.0359189994633198,0.00334500009194016,0.027496000751853,0.00227899989113212,-0.00863599963486195,0.0084380004554987,0.0107119996100664,0.0202029999345541,-0.0232999995350838,-0.0276640001684427,-0.00259799999184906,0.0152820004150271,-0.0257719997316599,-0.0355530008673668,0.00298299989663064,0.023132000118494,0.0163119994103909,0.0536499992012978,-0.0106199998408556,0.0360720008611679,-0.0251160003244877,0.015433999709785,-0.00445900019258261,0.0365599989891052,-0.0235600005835295,0.0117490002885461,0.00383200007490814,-0.0264740008860826,0.00607299990952015,0.0467219986021519,0.0410160012543201,0.00160399999003857,0.0127640003338456,-0.0203249994665384,0.00976600032299757,-0.0168299991637468,0.0205380003899336,0.00698499986901879,0.00246399990282953,0.044403001666069,-0.012626999989152,-0.00457399990409613,0.0331120006740093,0.0191500000655651,0.00689700013026595,0.000118000003567431,0.0223689991980791,0.0324099995195866,0.014403  -0.0209377761930227,0.0149789853021502,0.0315901860594749,0.00892018247395754,0.0359237603843212,0.00334544363431633,0.02749964594841,0.00227930210530758,-0.00863714516162872,0.00843911897391081,0.0107134198769927,0.0202056784182787,-0.0233030896633863,-0.0276676677167416,-0.00259834458120167,0.0152840269729495,-0.0257754176855087,-0.0355577133595943,0.00298339547589421,0.0231350678950548,0.0163141619414091,0.0536571145057678,-0.0106214080005884,0.0360767841339111,-0.0251193307340145,0.0154360458254814,-0.00445959158241749,0.0365648455917835,-0.0235631242394447,0.0117505583912134,0.00383250811137259,-0.0264775119721889,0.0060738050378859,0.0467281937599182,0.0410214401781559,0.00160421268083155,0.0127656925469637,-0.0203276947140694,0.00976729486137629,-0.0168322306126356,0.0205407235771418,0.00698592606931925,0.00246432656422257,0.0444088876247406,-0.0126286745071411,-0.0045746061950922,0.0331163927912712,0.0191525388509035,0.00689791468903422,0.000118015646876302,0.0223719645291567,0.032414298504591,0.01440
# 1     VSDEMO01  test_table_update    300  94.67       Average product  Review3  needs improvement          27  -0.00658799987286329,0.0162049997597933,0.0359800010919571,0.0123140001669526,0.017578000202775,0.00482599996030331,0.032744999974966,-0.0254670009016991,-0.0255580004304647,0.0134049998596311,0.011307000182569,0.00830799993127584,0.00202000001445413,-0.00429899990558624,-0.00389899988658726,0.00665300013497472,-0.0352779999375343,-0.0184480007737875,0.00847600027918816,0.0261840000748634,0.00635100016370416,0.0496830008924007,-0.00286099989898503,0.0355530008673668,-0.0217439997941256,0.00808699987828732,0.014380999840796,0.0338129997253418,-0.00187399995047599,0.016372999176383,-0.00170499994419515,-0.0130230002105236,0.00696199992671609,0.0455019995570183,0.0240330006927252,-0.00127200002316386,0.0234220009297132,-0.028702000156045,0.0164640005677938,-0.0308989994227886,0.0137329995632172,0.0146869998425245,-0.0148620000109076,0.0480649992823601,-0.0213619992136955,-0.0206300001591444,0.0448909997940063,0.0121309999376535,0.0127640003338456,-0.00574899977073073,0.0264890007674694,0.0181269999593496,-0.0097  -0.00658721383661032,0.0162030663341284,0.0359757095575333,0.0123125314712524,0.017575902864337,0.00482542440295219,0.032741092145443,-0.0254639629274607,-0.0255549512803555,0.0134034007787704,0.011305651627481,0.00830700900405645,0.00201975903473794,-0.00429848721250892,-0.00389853469096124,0.00665220664814115,-0.0352737903594971,-0.0184457991272211,0.00847498886287212,0.0261808764189482,0.00635024253278971,0.0496770739555359,-0.00286065856926143,0.0355487577617168,-0.0217414051294327,0.00808603502810001,0.0143792843446136,0.0338089652359486,-0.00187377643305808,0.0163710452616215,-0.00170479656662792,-0.0130214467644691,0.00696116918697953,0.0454965718090534,0.0240301340818405,-0.00127184833399951,0.0234192069619894,-0.0286985766142607,0.0164620373398066,-0.0308953132480383,0.0137313613668084,0.0146852480247617,-0.0148602267727256,0.0480592660605907,-0.0213594511151314,-0.0206275396049023,0.0448856428265572,0.0121295526623726,0.0127624776214361,-0.00574831385165453,0.0264858398586512,0.0181248374283314,-0.0
# 2     VSDEMO01  test_table_update    200  97.32   Bad quality product  Review2     quality is bad          26  -0.00617199996486306,0.0121990004554391,0.0231630001217127,0.0151899997144938,0.0336910001933575,0.00325000006705523,0.0286410003900528,0.0060419999063015,0.00757599994540215,0.0277709998190403,-0.0127870002761483,0.0151370000094175,-0.0377199985086918,-0.0357670001685619,-0.000796000007539988,0.0175630003213882,-0.0269169993698597,-0.0389400012791157,0.00943799968808889,0.0221859999001026,-0.00207899999804795,0.0389400012791157,-0.0147550003603101,0.0357670001685619,-0.0321040004491806,-0.017272999510169,0.00473400019109249,0.0309749990701675,-0.0268399994820356,0.0157469995319843,0.00514200003817677,-0.0285950005054474,0.00930000003427267,0.0318600013852119,0.0340580008924007,-0.00929300021380186,0.0153270000591874,-0.0239870008081198,0.00162300001829863,-0.0182339996099472,0.00534400017932057,0.0219570007175207,0.00795000046491623,0.0496830008924007,-0.00205000001005828,-0.0128170000389218,0.0378420017659664,0.0123439999297261,-0.0101389996707439,-0.00325799989514053,0.00338899996131659,0.0255580004304647,  -0.0061704465188086,0.0121959298849106,0.0231571700423956,0.0151861757040024,0.0336825177073479,0.00324918190017343,0.0286337900906801,0.00604047905653715,0.00757409306243062,0.0277640093117952,-0.0127837816253304,0.0151331899687648,-0.037710502743721,-0.0357579961419106,-0.000795799656771123,0.017558578401804,-0.0269102230668068,-0.0389302000403404,0.00943562388420105,0.0221804156899452,-0.00207847659476101,0.0389302000403404,-0.0147512862458825,0.0357579961419106,-0.0320959202945232,-0.0172686520963907,0.00473280856385827,0.0309672020375729,-0.0268332436680794,0.0157430358231068,0.00514070549979806,-0.0285878032445908,0.00929765868932009,0.0318519808351994,0.034049428999424,-0.00929066073149443,0.0153231415897608,-0.023980962112546,0.00162259151693434,-0.0182294100522995,0.00534265488386154,0.0219514742493629,0.00794799905270338,0.0496704950928688,-0.00204948405735195,-0.0128137739375234,0.0378324761986732,0.0123408930376172,-0.0101364478468895,-0.00325717986561358,0.00338814686983824,0.0255515668541193,0.0
# 3     VSDEMO01  test_table_update    100  99.99          Good product  Review1    Product is good          25  -0.0131149999797344,-0.00291400006972253,0.0238949991762638,0.00940699968487024,0.0286710001528263,-0.0168910007923841,0.0419620014727116,-0.00778600014746189,0.00227000005543232,0.0262299999594688,0.0125660002231598,0.0260160006582737,0.00492900004610419,-0.0120320003479719,-0.0123829999938607,0.00266100000590086,-0.0228419993072748,-0.0367739982903004,-0.00762199983000755,0.0251010004431009,-0.0159450005739927,0.0443729981780052,0.012618999928236,0.0249019991606474,-0.00851400010287762,-0.00230000005103648,0.0141599997878075,0.0214389991015196,-0.020736999809742,0.013213999569416,0.00305699999444187,-0.0458370000123978,0.00810199975967407,0.071044996380806,0.0345150008797646,0.00492099998518825,0.0166020002216101,-0.0326839983463287,0.0135040003806353,-0.0260310005396605,0.0112920003011823,0.00367200002074242,0.00733199995011091,0.0304869990795851,-0.0119169997051358,0.00739700021222234,0.0279079992324114,0.0217129997909069,0.0015379999531433,-0.00633199978619814,0.022079000249505,0.017119999974966,0.017105  -0.0131125822663307,-0.00291346292942762,0.0238905940204859,0.00940526556223631,0.0286657158285379,-0.0168878864496946,0.041954267770052,-0.00778456497937441,0.00226958165876567,0.0262251645326614,0.0125636840239167,0.0260112043470144,0.00492809154093266,-0.0120297828689218,-0.0123807173222303,0.00266050943173468,-0.0228377878665924,-0.0367672182619572,-0.00762059492990375,0.0250963736325502,-0.0159420613199472,0.0443648174405098,0.0126166734844446,0.0248974096029997,-0.00851243082433939,-0.00229957606643438,0.0141573892906308,0.0214350465685129,-0.0207331776618958,0.0132115641608834,0.00305643654428422,-0.0458285510540009,0.00810050591826439,0.0710318982601166,0.0345086380839348,0.00492009287700057,0.0165989398956299,-0.0326779745519161,0.0135015109553933,-0.026026202365756,0.011289918795228,0.00367132318206131,0.00733064860105515,0.0304813794791698,-0.0119148027151823,0.0073956367559731,0.0279028546065092,0.0217089969664812,0.00153771648183465,-0.00633083237335086,0.022074930369854,0.0171168446540833,0.0171

# %% [markdown]
# ### Delete contents of 'test_table_update' from Vector Store.

# %%
updated_vs.update(object_names='test_table_update',
                  alter_operation="DELETE",
                  update_style="MINOR")

# %%
op = updated_vs.get_indexes_embeddings()

# %%
op.loc[op['TableName'] == 'test_table_update']
# Out:
# Empty DataFrame
# Columns: [DataBaseName, TableName, rev_id, aid, prodsummary, rev_name, rev_text, TD_TEMP_ID, vector_index, vector_index_normalized]
# Index: []

# %% [markdown]
# ### Users can add or delete metadata_columns from the current Vector Store.

# %%
vs.update(metadata_columns = ["rev_name"],
          metadata_operation = "DELETE")
# Out:
# Vector store aionprem1 update started.
# Use the 'status()' api to check the status of the operation.

# %%
vs.get_details()
# Out:
#      vs_name     store_type description database_name  sample_size                   embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold search_numcluster ef_search initial_centroids_method train_numcluster max_iternum stop_threshold  seed num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects                    document_objects document_columns   document_indexes prompt vector_column               chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens             vs_status                                                                                base_url_embeddings                                                                     base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated                              metadata_columns base_url_content_safety base_url_topic_control base_url_jailbreak_detection content_safety_model topic_control_model guardrails num_NodesPerGraph onnx_model_table onnx_tokenizer_table onnx_model_id onnx_tokenizer_id onnx_model_column onnx_tokenizer_column onnx_model_id_column onnx_tokenizer_id_column embedding_datatype  use_simd base_url_vlm vlm_model  maximal_marginal_relevance  lambda_multiplier permission
# 0  aionprem1  content-based        None      VSDEMO01           20  nvidia/llama-3.2-nv-embedqa-1b-v2             2048  COSINE   VECTORDISTANCE     10             None              None      None                     None             None        None           None  None     None      None            None            None               None             None             None             None            None            None  ["\"VSDEMO01\".amazon_reviews_25"]     ["rev_text"]  ["rev_id", "aid"]   None  vector_index  mistralai/mistral-7b-instruct-v0.3            0.2                       None               60                        8192  UPDATING (FINISHING)  https://gpudev1-modelops.labs.teradata.com/serving/nvidia-llama-32-nv-embedqa-1b-v2/v1/embeddings  https://gpudev1-modelops.labs.teradata.com/serving/mistralai-mistral-7b-instruct-v03/v1            None             None          None            None       None             None               None        None          None                None  2025-10-21 12:08:52.792655+00:00  [{"name": "prodsummary", "description": ""}]                    None                   None                         None                 None                None       None              None             None                 None          None              None              None                  None                 None                     None           VECTOR32         1         None      None                           0                0.5      ADMIN

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Asking on the Updated Vector Store
#
# Once you've updated the vector store, you can seamlessly perform a **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.
#
# #### 🛠 Steps to Perform on the Updated Vector Store
#
# 1. **Similarity Search**
#    - Use the `similarity_search()` method to find the most relevant matches for your input question based on the updated configuration.

# %%
question = 'Which book are all the reviews talking about?'
response = updated_vs.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    rev_text  index_label
# 0  0.268049     VSDEMO01  amazon_reviews_25  A2X4HE21JTAL98  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                       Anything I"ve read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran"s work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that. The poetic style, the aphorisms, the parables, the almost biblical feel, are all just what over-worked, over-stressed, modern and spiritually starved worldly people need.            2
# 1  0.241410     VSDEMO01  amazon_reviews_25  A3FFNE1DR5SI1W  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Can"t say enough about Kahlil Gibran"s work among this piece. Everybody in the whole world should read this! There is almost too much to take in, really appreciate and put towards our daily lives. In my opinion, it is just one of the most beautiful literature pieces ever written. Would recommend to as a gift for anyone spiritual/poetic/philosophy/educational piece or just something to enjoy here and there. 5 stars for sure!            4
# 2  0.239308     VSDEMO01  amazon_reviews_25   A5E9TSD20U9PR  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               For those who don"t know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions. This is a relationship with a man"s work you won"t regret having.            5
# 3  0.223887     VSDEMO01  amazon_reviews_25   AUTNO7VDY4H4A  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Loved this book since first I read it, years gone by.  Purchased this copy for a friend who has not ever read Gibran.            6
# 4  0.182999     VSDEMO01  amazon_reviews_25  A12387207U8U24  000100039X                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              As you read, Gibran"s poetry brings spiritual and visual beauty to life within you. Gibran is justly famous for rich metaphors that brilliantly highlight the pursuit of Truth and Goodness amidst all the darkness and light of human nature.            7
# 5  0.258010     VSDEMO01  amazon_reviews_25  A19N3FCQCLJYUA  000100039X                                      I discovered The Prophet fifty years ago in college and have read it dozens of times since then.  Now, in addition to my beat up hard copy, I have a portable e-copy.  If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it.  It doesn"t care how you picture, name or define &#34;God&#34; or whether you give him a gender and a personality.  It just cuts to the heart of how to live and how to relate to others.  If Jesus and the Buddha teamed up to write a book, it might come out like this.When I first read it, I found some passages difficult to grasp.  Looking back, I now think that it was not because they were hard to understand, but because I did not want to hear gently spoken, intelligently phrased ideas that contradicted my own.  Now, if I could have only one book, this would probably be it.            3
# 6  0.291525     VSDEMO01  amazon_reviews_25  A2I35JB67U20C0  000100039X  When I was in college in the 70"s this book had a revival and I did not read it then.  Recently a friend (who is 90) and I were talking about work and she said: &quot;work is love made visible,&quot; and told me it was from the Prophet.  I though that was so beautiful I got the book and was not disappointed.You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible.He says it WAY better that I do and says much more in just a few paragraphs.  But as you can see from the example, what he says is not religious, but positive ways of looking at things.  Since I rediscoverd the book I have given away many copies and everyone I have given it to sincerly thanked me.            1
# 7  0.298274     VSDEMO01  amazon_reviews_25  A1KQ80Y692CDOI  000100039X                                                                                                                                                                                                     I read this about a year ago and can"t recall a great deal of the book. From what I do recall it was like a poem all the way through. While the writing was beautiful, I found it ambiguous and befuddled with meaning that I could not identify with. When Gibran speaks of God, I cannot identify because I have since abandoned those philosophies. It is thus difficult to revisit them in this book. I have the feeling a may have missed something great about this book. Indeed, I pulled wisdom from parts, but rather than go back and read it again, for now, perhaps I will move on to another of the many books out there that are enlightening and worth reading. Someday, I would like to read this again and dig deeper.            0

# %% [markdown]
# 2. **Prepare the Response**
#    - After retrieving the search results, use the `prepare_response()` function to generate a user-friendly, natural language response based on the most relevant matches.

# %%
question = 'Which book are all the reviews talking about?'
response = updated_vs.prepare_response(question=question, similarity_results=response)

# %%
print(response)
# Out:
# The book all the reviews are talking about is "The Prophet" by Kahlil Gibran.

# %% [markdown]
# 3. **Ask the Updated Vector Store**
#    - Combine these operations using the `ask()` method, which performs the search and generates the response in one call, ensuring faster and more efficient retrieval of information.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = updated_vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are several reviews that mention the book as inspiring. Here are a few examples:
#
# review_id: 0
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: Anything I've read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran's work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that.
#
# review_id: 2
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: For those who don't know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions.
#
# review_id: 3
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it. It doesn't care how you picture, name or define "God" or whether you give him a gender and a personality. It just cuts to the heart of how to live and how to relate to others. If Jesus and the Buddha teamed up to write a book, it might come out like this.
#
# review_id: 4
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible. He says it WAY better that I do and says much more in just a few paragraphs. But as you can see from the example, what he says is not religious, but positive ways of looking at things.
#
# review_id: 5
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: Can't say enough about Kahlil Gibran's work among this piece. Everybody in the whole world should read this! There is almost too much to take in, really appreciate and put towards our daily lives. In my opinion, it is just one of the most beautiful literature pieces ever written.
#
# review_id: 6
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: As you read, Gibran's poetry brings spiritual and visual beauty to life within you. Gibran is justly famous for rich metaphors that brilliantly highlight the pursuit of Truth and Goodness amidst all the darkness and light of human nature.

# %% [markdown]
# ### 🛠 Instantiating a Content Based Vector Store using ONNX Embeddings
#
# We can also create an instance of a content-based Vector Store with the ONNX model and tokenizer stored using `TeradataAI` class
# Please refer to `teradata_text_analytics_with_onnx.ipynb` notebook to understand how to initialize an ONNX model with TeradataAI
#
# Below examples show how we can create content-based stores using an ONNX model with `model_id` as "td-small-m1" and tokenizer with tokenizer_id as `td-small-m1-tokenizer` already stored in default tables in Teradata Vantage.

# %%
llm_onnx = TeradataAI(api_type = 'onnx',
                    model_name = "bge-small-v1.5",
                    model_id = "td-small-m1",
                    tokenizer_id = "td-small-m1-tokenizer")
# Out:
# Retrieving model id 'td-small-m1' from td_genai_byom_models
# Retrieving tokenizer id 'td-small-m1-tokenizer' from td_genai_byom_tokenizers

# %%
vs2 = VectorStore(name = "aionprem_onnx")

# Just pass the initialized TeradataAI object with api type as onnx to create the Vector Store
# Note: If the VS is initialized with ONNX , embeddings_dims are not accepted.
vs2.create(embeddings_model=llm_onnx,
          object_names = "amazon_reviews_25",
          data_columns = "rev_text",
          )
# Out:
# Vector store aionprem_onnx creation started.
# Use the 'status()' api to check the status of the operation.

# %%
vs2.status()
# Out:
#          vs_name status
# 0  aionprem_onnx  READY

# %%
vs2.similarity_search("Books with positive reviews")
# Out:
# similar_objects_count:10
# similar_objects:
#       score DataBaseName          TableName  TD_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      rev_text  index_label
# 0  0.498612     VSDEMO01  amazon_reviews_25     10                                                                                                                                                               I first read THE PROPHET in college back in the 60"s. The book had a revival as did anything metaphysical in the turbulent 60"s. It had a profound effect on me and became a book I always took with me. After graduation I joined the Peace Corps and during stressful training in country (Liberia) at times of illness and the night before I left, this book gave me great comfort. I read it before I married, just before and again after my children were born and again after two near fatal illnesses. I am always amazed that there is a chapter that reaches out to you, grabs you and offers both comfort and hope for the future.Gibran offers timeless insights and love with each word. I think that we as a nation should read AND learn the lessons here. It is definitely a time for thought and reflection this book could guide us through.            2
# 1  0.474132     VSDEMO01  amazon_reviews_25      8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 For those who don"t know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions. This is a relationship with a man"s work you won"t regret having.            4
# 2  0.465519     VSDEMO01  amazon_reviews_25     18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This book has been a classic for many years. It has so much wisdom in it that it can be read numerous times and new things will come out each time. My favorite chapter is the one on children.            5
# 3  0.461738     VSDEMO01  amazon_reviews_25     20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       This book is everything that is simple, delicate, true, and beautiful.I have read few books so touching and enlightening; &quot;The Prophet&quot; is a true masterpiece that has that feeling of ancient wisdom in it. The wisdom of the text is gentle, yet insistent, it lets you understand things you"ve always known.My feelings defy description.            6
# 4  0.455915     VSDEMO01  amazon_reviews_25     12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it..            8
# 5  0.453015     VSDEMO01  amazon_reviews_25      2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          An amazing work. Realizing extensive use of Biblical imagery and sentence structure, &#34;The Prophet&#34; by Khalil Gibran is a literary classic. Influencing the Free Love movement of the 1960"s, Gibran"s master work explores themes of love, longing and loss.            9
# 6  0.460805     VSDEMO01  amazon_reviews_25     21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane.            7
# 7  0.493132     VSDEMO01  amazon_reviews_25      6  Cool book, I really like the quality of the production.  Black clothbound with gold embossing and nice paper, looks to be cotton rag.  I am proud to include it in my collection.  Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life.  The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus.  I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter.  Excellent for busy people or commuters!            3
# 8  0.507295     VSDEMO01  amazon_reviews_25     15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the  author, it has to be consumed slowly and perhaps revisited but leaves you  pretty heady and clear about certain things.            1
# 9  0.537547     VSDEMO01  amazon_reviews_25     24                                                                                    When I was in college in the 70"s this book had a revival and I did not read it then.  Recently a friend (who is 90) and I were talking about work and she said: &quot;work is love made visible,&quot; and told me it was from the Prophet.  I though that was so beautiful I got the book and was not disappointed.You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible.He says it WAY better that I do and says much more in just a few paragraphs.  But as you can see from the example, what he says is not religious, but positive ways of looking at things.  Since I rediscoverd the book I have given away many copies and everyone I have given it to sincerly thanked me.            0)

# %%
vs2.destroy()
# Out:
# Vector store aionprem_onnx destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# #### Using ModelUrlParams class to initialize common model and URL information
#
# Use the model_urls parameters to pass in model and url related information while creating Vector with from_* methods

# %%
model_urls = ModelUrlParams(embedding="nvidia/llama-3.2-nv-embedqa-1b-v2",
                            embeddings_base_url = embeddings_url,
                            chat_completion_model="mistralai/mistral-7b-instruct-v0.3",
                            completions_base_url = completions_url)

# %% [markdown]
# ### 🛠 Instantiating a Content Based Vector Store using `from_datasets` method.
#
# We can also create an instance of a content-based Vector Store directly using the `from_datasets` of the VectorStore class.
#
# **from_datasets()**
#    - Creates a new 'content-based' vector store from the input dataset(s) containing table(s) or teradataml DataFrames(s).
#    - `name` , `datasets` and `data_columns` are mandatory arguments (in addition to the mandatory NIM arguments) and we can also provide other arguments related to creation and search metrics.
#
#
# Below examples show how we can create content-based stores using these methods

# %%
# Creating an instance of VectorStore using from_datasets() method
vs_instance_dataset = VectorStore.from_datasets(name = "vs_example_from_datasets",
                                                data = input_data,
                                                data_columns = "rev_text",
                                                key_columns = ["rev_id", "aid"],
                                                metadata_columns = ["prodsummary"],
                                                model_urls = model_urls,
                                                embeddings_dims = 2048,
                                                chat_completion_max_tokens = 8192
                                                )
# Out:
# Vector store vs_example_from_datasets creation started.
# Use the 'status()' api to check the status of the operation.

# %%
# Check status of the store
vs_instance_dataset.status()
# Out:
#                     vs_name status
# 0  vs_example_from_datasets  READY

# %% [markdown]
# ### ✨ Adding and Deleting datasets
#
# You can **add** or **delete** datasets from an existing Vector Store using the `add_datasets()` and `delete_datasests()` methods.
#
# Note: Deleting datasets only works if the VectorStore is initialized using `key_columns`

# %%
# Loading example data
load_data('byom', 'amazon_reviews_10')
amazon_reviews_10 = DataFrame('amazon_reviews_10')
# Out:
# WARNING: Skipped loading table amazon_reviews_10 since it already exists in the database.

# %%
vs_instance_dataset.add_datasets(data= amazon_reviews_10)
# Out:
# Vector store vs_example_from_datasets update started.
# Use the 'status()' api to check the status of the operation.

# %%
vs_instance_dataset.get_details()
# Out:
#                     vs_name     store_type description  database_name  sample_size                   embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold p_value search_numcluster  ef_search initial_centroids_method train_numcluster max_iternum stop_threshold  seed num_init  num_layer  ef_construction  num_connPerNode  maxNum_connPerNode  apply_heuristics include_objects                                                        document_objects document_columns   document_indexes prompt vector_column               chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status                                                                                base_url_embeddings                                                                     base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated permission
# 0  vs_example_from_datasets  content-based        None  TERADATAGENAI           20  nvidia/llama-3.2-nv-embedqa-1b-v2             2048  COSINE             HNSW      7             None    None              None         32                     None             None        None           None    10     None          6               32               32                  32                 1            None  ["TERADATAGENAI.amazon_reviews_25", "TERADATAGENAI.amazon_reviews_10"]     ["rev_text"]  ["rev_id", "aid"]   None  vector_index  mistralai/mistral-7b-instruct-v0.3            0.2                       None               60                        8192     READY  https://gpudev1-modelops.labs.teradata.com/serving/nvidia-llama-32-nv-embedqa-1b-v2/v1/embeddings  https://gpudev1-modelops.labs.teradata.com/serving/mistralai-mistral-7b-instruct-v03/v1            None             None          None            None       None             None               None        None          None                None  2025-09-03 05:40:43.595614+00:00      ADMIN

# %%
vs_instance_dataset.delete_datasets(data=amazon_reviews_10)
# Out:
# Vector store vs_example_from_datasets update started.
# Use the 'status()' api to check the status of the operation.

# %%
# Check the status of the updated store.
vs_instance_dataset.status()
# Out:
#                     vs_name status
# 0  vs_example_from_datasets  READY

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Ask
#
# Using the vector store instance, you can do **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.
#
# #### 🛠 Steps to Perform on the Updated Vector Store
#
# 1. **Similarity Search**
#    - Use the `similarity_search()` method to find the most relevant matches for your input question based on the updated configuration.

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_dataset.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                              prodsummary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      rev_text  index_label
# 0  0.402130     VSDEMO01  amazon_reviews_25  A2KU9IU07LOJS1  000100039X                  Great classic that everyone should read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This book has been a classic for many years. It has so much wisdom in it that it can be read numerous times and new things will come out each time. My favorite chapter is the one on children.            2
# 1  0.381129     VSDEMO01  amazon_reviews_25  A26GKZPS079GFF  000100039X                  Touches my heart.. again and.. again...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         I would have to say that this is the best book I"ve ever read.. I could feel every word deep in my heart everytime, of the many times I"ve read it!  I would never get enough of it! its a treasure..            4
# 2  0.351030     VSDEMO01  amazon_reviews_25  A1BM81XB4QHOA3  000100039X                          Must Read for Life Afficianados                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    This book provides a reflection that you can apply to your own life.And, a way for you to try and assess whether you are truly doing the right thing and making the most of your short time on this plane.            5
# 3  0.330722     VSDEMO01  amazon_reviews_25  A2S166WSCFIFP5  000100039X                                             close to god                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  This is one my must have books. It is a masterpiece of spirituality. I"ll be the first to admit, its literary quality isn"t much. It is rather simplistically written, but the message behind it is so powerful that you have to read it. It will take you to enlightenment.            6
# 4  0.291029     VSDEMO01  amazon_reviews_25  A1TT4CY55WLHAR  000100039X  textured paper, old-style typography, and leather cover                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I have the 1972 version, bought in 1974. The 1972 version originally had a dust jacket but my dust jacket is long gone. This particular rendition has had many re-printings, for a reason: it"s very popular. The textured paper, old-style typography, and leather cover are better than a plain-old paperback. The size is diminutive, which is perfect for this book.            8
# 5  0.290102     VSDEMO01  amazon_reviews_25   ARDQ9KNB8K22N  000100039X                                """The Prophet"" is cool"  Cool book, I really like the quality of the production.  Black clothbound with gold embossing and nice paper, looks to be cotton rag.  I am proud to include it in my collection.  Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life.  The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus.  I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter.  Excellent for busy people or commuters!            9
# 6  0.321502     VSDEMO01  amazon_reviews_25  A3FI0744PG1WYG  000100039X                                              The Prophet                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This is a timeless classic.  Over the years I"ve given it as a gift more times than I can count, and will continue to do so.  Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives.  So easy to read over and over.            7
# 7  0.390674     VSDEMO01  amazon_reviews_25   AUTNO7VDY4H4A  000100039X                    A great book, buying it for a friend.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Loved this book since first I read it, years gone by.  Purchased this copy for a friend who has not ever read Gibran.            3
# 8  0.468151     VSDEMO01  amazon_reviews_25  A1340OFLZBW5NG  000100039X          Perhaps the greatest book that I have ever read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it..            1
# 9  0.515308     VSDEMO01  amazon_reviews_25  A2WVHIRDMLM82E  000100039X                                                  Amazing                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     This book has so much you can take out of it to use in your real life. Amazing, and one of my favorite reads of all time.            0

# %% [markdown]
# 2. **Prepare the Response**
#    - After retrieving the search results, use the `prepare_response()` function to generate a user-friendly, natural language response based on the most relevant matches.

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_dataset.prepare_response(question=question, similarity_results=response)
print(response)
# Out:
# The book that all the reviews are talking about is "The Prophet" by an unspecified author.

# %% [markdown]
# 3. **Ask the Updated Vector Store**
#    - Combine these operations using the `ask()` method, which performs the search and generates the response in one call, ensuring faster and more efficient retrieval of information.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = vs_instance_dataset.ask(question=question, prompt=custom_prompt)

# %%
# Destroy the Vector Store instance
vs_instance_dataset.destroy()
# Out:
# Vector store vs_example_from_datasets destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### 🛠 Creating a store with `add_datasets` method
#
# Users can also create a content based Vector Store directly using the `add_datasets`

# %%
vs_instance_dataset = VectorStore()

vs_instance_dataset.add_datasets(name = "vs_example_add_datasets",
                                 data = input_data,
                                 data_columns = "rev_text",
                                 key_columns = ["rev_id", "aid"],
                                 embeddings_dims = 2048,
                                 chat_completion_max_tokens = 8192,
                                model_urls = model_urls
                                 )

# %%
vs_instance_dataset.status()
# Out:
#                    vs_name status
# 0  vs_example_add_datasets  READY

# %%
# Destroy the vector store
vs_instance_dataset.destroy()
# Out:
# Vector store vs_example_add_datasets destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### 🛠 Instantiating a Content Based Vector Store using `from_texts` method
#
#  **from_texts()**
#    - Creates a new 'content-based' vector store from the input text(s) or list of text(s).
#    - Internally the texts are converted into table and stored to Teradata Vantage.

# %%
# Sample text documents for demonstration
sample_texts = [
    "Teradata Vantage is a modern data platform that unifies data lakes, data warehouses, analytics, and new data sources.",
    "Machine learning models can be deployed directly in Teradata Vantage for in-database analytics and scoring.",
    "Vector databases enable semantic search capabilities by storing and querying high-dimensional embeddings.",
    "Natural language processing with large language models has revolutionized how we interact with data.",
    "SQL is the standard language for managing and querying relational databases across various platforms.",
    "Data science workflows often involve data preparation, model training, validation, and deployment phases.",
    "Cloud computing provides scalable infrastructure for modern data analytics and machine learning workloads.",
    "Real-time analytics enable organizations to make data-driven decisions with minimal latency."
]

print(f"Prepared {len(sample_texts)} text samples for vector store creation")
# Out:
# Prepared 8 text samples for vector store creation

# %%
# Create text-based vector store
try:
    vs_instance_texts = VectorStore.from_texts(name="vs_example_from_texts",
                                               texts=sample_texts,
                                               embedding = "nvidia/llama-3.2-nv-embedqa-1b-v2",
                                               embeddings_dims = 2048,
                                               embeddings_base_url = embeddings_url,
                                               completions_base_url = completions_url,
                                               chat_completion_model = "mistralai/mistral-7b-instruct-v0.3",
                                               chat_completion_max_tokens = 8192
                                               )
    
    print("Text-based vector store created successfully!")
    print(f"Vector store name: {vs_instance_texts.name}")
except Exception as e:
    print(f"Error creating text-based vector store: {e}")
# Out:
# Vector store vs_example_from_texts creation started.
# Use the 'status()' api to check the status of the operation.
# Text-based vector store created successfully!
# Vector store name: vs_example_from_texts

# %%
# Check the status of the store.
vs_instance_texts.status()
# Out:
#                  vs_name status
# 0  vs_example_from_texts  READY

# %%
# Additional texts to add
additional_texts = [
    "Artificial intelligence is transforming industries through automation and intelligent decision-making.",
    "Data governance ensures data quality, security, and compliance across enterprise systems.",
    "Business intelligence tools help organizations visualize and understand their data patterns."
]

# Add texts to existing vector store
try:
    vs_instance_texts.add_texts(texts=additional_texts)
    print(f"Successfully added {len(additional_texts)} additional texts to the vector store")
except Exception as e:
    print(f"Error adding texts: {e}")
# Out:
# Vector store vs_example_from_texts update started.
# Use the 'status()' api to check the status of the operation.
# Successfully added 3 additional texts to the vector store

# %%
# Check if update is complete.
vs_instance_texts.status()
# Out:
#                  vs_name                status  retry_after
# 0  vs_example_from_texts  UPDATING (FINISHING)           60

# %% [markdown]
# ### 🛠 Creating a store with texts and the  `add_texts` method
#
# Users can also create a content based Vector Store by passing in the texts / list of texts to the `add_texts` method

# %%
vs_texts = VectorStore()
vs_texts.add_texts(name="vs_example_add_texts",
                   texts=sample_texts,
                   embedding = "nvidia/llama-3.2-nv-embedqa-1b-v2",
                   embeddings_dims = 2048,
                   embeddings_base_url = embeddings_url,
                   completions_base_url = completions_url,
                   chat_completion_model = "mistralai/mistral-7b-instruct-v0.3",
                   chat_completion_max_tokens = 8192
                  )

# %%
vs_texts.status()

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Ask
#
# Using the vector store instance created from texts, you can do **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_texts.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score   DataBaseName                         TableName  TD_ID                                                                                                        text  index_label
# 0  0.221058  TERADATAGENAI  ml__from_pandas_1756880087597849      1  Cloud computing provides scalable infrastructure for modern data analytics and machine learning workloads.            2
# 1  0.176454  TERADATAGENAI  ml__from_pandas_1756880087597849      5                Real-time analytics enable organizations to make data-driven decisions with minimal latency.            4
# 2  0.171348  TERADATAGENAI  ml__from_pandas_1756880087597849      2   Data science workflows often involve data preparation, model training, validation, and deployment phases.            5
# 3  0.171348  TERADATAGENAI  ml__from_pandas_1756880087597849      2   Data science workflows often involve data preparation, model training, validation, and deployment phases.            6
# 4  0.221058  TERADATAGENAI  ml__from_pandas_1756880087597849      1  Cloud computing provides scalable infrastructure for modern data analytics and machine learning workloads.            3
# 5  0.296849  TERADATAGENAI  ml__from_pandas_1756880087597849      4        Natural language processing with large language models has revolutionized how we interact with data.            1
# 6  0.420267  TERADATAGENAI  ml__from_pandas_1756880087597849      6       SQL is the standard language for managing and querying relational databases across various platforms.            0

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_texts.prepare_response(question=question, similarity_results=response)
print(response)
# Out:
# The reviews do not explicitly mention a specific book. However, they discuss topics related to data science, SQL, natural language processing, cloud computing, real-time analytics, and data science workflows. These topics are commonly found in books about data science, machine learning, and artificial intelligence. Therefore, it can be inferred that the reviews might be about a book related to data science, machine learning, or artificial intelligence.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = vs_instance_texts.ask(question=question, prompt=custom_prompt)

# %%
response
# Out:
# 'Based on the provided data, there are no reviews that explicitly mention the books as inspiring. The data only contains reviews about SQL, natural language processing, cloud computing, data science workflows, and Teradata Vantage.'

# %%
# Destroy the Vector Store Instances
vs_instance_texts.destroy()
vs_texts.destroy()

# %% [markdown]
# ## 🔌 Disconnect
# - **Terminate All Active Connections**
#    - This operation terminates all active connections to the vector store database.

# %%
VSManager.disconnect()
# Out:
# Database connection closed.

# %%
remove_context()
# Out:
# True
