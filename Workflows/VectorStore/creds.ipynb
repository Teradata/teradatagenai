# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.extend([r'C:\\Aanchal\\office\\git\\NexusAI',r'C:\\Aanchal\\office\\git\\pyTeradata'])

# %%
from teradataml import *
from teradataml import create_context, set_config_params, list_base_envs, list_user_envs, create_env
user="gpu_user"
password="gpu_user"
host = "44.231.243.196"
eng = create_context(host=host, username=user, password=password)
print(eng)
auth_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlcyI6WyJURF9EQVRBX1NDSUVOVElTVCJdLCJwcmVmZXJyZWRfdXNlcm5hbWUiOiJncHVfdXNlciIsImlzcyI6IlVFUy1TVkMifQ.U18gUKEbpKxIEme-oINvnkeJhSPeXVAztI_pRBHWTj4"
account_id = "acc-ed9f42ad05"
pod= "tced9f42"
ues_url = f"https://teracloud-pod-services-pod-account-service.{pod}.production.pods.teracloud.ninja/v1/accounts/{account_id}/user-environment-service/api/v1/"
set_auth_token(auth_token=auth_token, ues_url=ues_url)
# Out:
# Engine(teradatasql://gpu_user:***@44.231.243.196)
# Authentication token is generated and set for the session.

# %%
from teradataml import list_user_envs

# %%
list_user_envs()
# Out:
# No user environment(s) found.

# %%
# VCE

from teradataml import create_context
import os
base_url = "https://TDICAZVSAZ0DV75.private.dev.cloud.teradata.com"
os.environ['TD_HOST'] = '10.91.160.4'
os.environ['TD_USERNAME'] = 'oaf'
os.environ['TD_PASSWORD'] = 'oaf'
os.environ['TD_BASE_URL'] = base_url
os.environ['TD_AUTH_MECH'] = 'BASIC'
create_context()
set_auth_token(base_url=base_url, auth_token="ass")

# %%
from teradataml import set_auth_token
set_auth_token(base_url=base_url, auth_token="ass")
# Out:
# ---------------------------------------------------------------------------
# TeradataMlException                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from teradataml import set_auth_token
# ----> 2 set_auth_token(base_url=base_url, auth_token="ass")
#
# File C:\\Aanchal\\office\\git\\pyTeradata\teradataml\telemetry_utils\queryband.py:51, in collect_queryband.<locals>.outer_wrapper.<locals>.inner_wrapper(*func_args, **func_kwargs)
#      46 @wraps(func)
#      47 def inner_wrapper(*func_args, **func_kwargs):
#      48     # Pass the required argument 'session_queryband' along with other
#      49     # expected arguments to collect_queryband() decorator which is
#      50     # imported as tdsqlalchemy_collect_queryband.
# ---> 51     return tdsqlalchemy_collect_queryband(session_queryband, *qb_deco_pos_args, **qb_deco_kwargs)(func)(*func_args, **func_kwargs)
#
# ...
