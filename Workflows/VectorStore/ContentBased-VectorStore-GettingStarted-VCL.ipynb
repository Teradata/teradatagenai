# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#         Getting Started with Content-Based Vector Store on VCL
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Introduction</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Vector stores are specialized databases designed for efficient storage, indexing, and searching of high-dimensional vector embeddings. These embeddings, generated by AI models, enable similarity search and power applications in machine learning, NLP, recommendation systems, and image/video retrieval.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# This notebook provides an in-depth exploration of vector stores in the Teradata Database, covering key concepts, vector embedding mechanisms, and efficient search techniques.
# </p>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Key Concepts</b></p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>What is a Vector Store?</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# A vector store contains a vectorized representation of data, typically created using embeddings from AI models. It allows for high-speed similarity searches beyond traditional keyword matching.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Vector embeddings are numerical representations of data (text, images, audio, etc.) mapped into a multi-dimensional space.
# </p>
#
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Each embedding is a vector that captures semantic or content-based relationships. For example:
# </p>
#
# <table style="font-size:16px;font-family:Arial;color:#00233C;border:1px solid black;">
#   <tr>
#     <th style="border:1px solid black;padding:5px;">Data Type</th>
#     <th style="border:1px solid black;padding:5px;">Example</th>
#     <th style="border:1px solid black;padding:5px;">Vector Representation</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Text</td>
#     <td style="border:1px solid black;padding:5px;">"King"</td>
#     <td style="border:1px solid black;padding:5px;">[0.12, 0.45, 0.67, ...]</td>
#   </tr>
#   <tr>
#     <td style="border:1px solid black;padding:5px;">Image</td>
#     <td style="border:1px solid black;padding:5px;">A picture of a cat</td>
#     <td style="border:1px solid black;padding:5px;">[0.23, 0.78, 0.55, ...]</td>
#   </tr>
# </table>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# <b>Embedding Generation is carried out by AI_TextEmbedding Function </b>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li>Enables text embedding generation using LLMs hosted.</b> (Performs a full-table scan)</li>
#     <li> Accepts different parameters, model endpoint, key, model args etc.</li>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>Vector Search</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Unlike traditional search methods, vector search understands the meaning behind a query. It provides relevant results by analyzing semantic relationships rather than exact keyword matches.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Common types of embeddings include:
# </p>
#
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
# <li>Word Embeddings</li>
# <li>Sentence Embeddings</li>
# <li>Document Embeddings</li>
# <li>Image Embeddings</li>
# <li>Audio Embeddings</li>
# </ul>
#
# ---
#
# <p style="font-size:24px;font-family:Arial;color:#00233C"><b>Vector Store in the Teradata Database</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# A vector in Teradata is a specialized column type called <b>Vector</b>.
# </p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# The <b>vector store</b> in Teradata consists of schemas and tables that enable vector search functionality.
# </p>
#
# <hr>
#
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>Vector Search Algorithms</b></p>
#
# <p style="font-size:16px;font-family:Arial;color:#00233C">
# Teradata supports three main search algorithms:
# </p>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>1. VectorDistance</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>Flat index</b> (performs a full-table scan)</li>
#   <li><b>Scalable and parallel search</b></li>
#   <li><b>Exact search approach</b></li>
#   <li>Suitable for <b>smaller datasets (<10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>2. Kmeans</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>IVF (Inverted Vector File) index</b> (organizes data into clusters)</li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial;color:#00233C"><b>3. HNSW</b></p>
# <ul style="font-size:16px;font-family:Arial;color:#00233C">
#   <li><b>HNSW (Hierarchical Navigable Small World) index</b></li>
#   <li><b>Graph-based Approximate Nearest Neighbors (ANN) search</b></li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <hr>
#
#
# <p style="font-size:20px;font-family:Arial;color:#00233C"><b>Types of Vector Store</b></p>
#
# <table style="font-size:15px; font-family:Arial; color:#00233C; width:100%; border:1px solid #ddd; border-collapse:collapse;">
#   <tr>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Type</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Description</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Use Case</th>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>1. Content-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>contents of a table</b> (or file/PDF converted to a table). Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>2. Metadata-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>metadata</b> of tables. Queries return the <b>top matching tables</b> based on similarity. Used in <b>SQL generation</b> for data retrieval.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Helps form textual responses by retrieving data from relevant tables for more precise answers.</td>
#   </tr>
#     <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>3. File-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built from contents of PDF file. Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#     <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>4. Embedding-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built from the <b>user generated embeddings</b> . Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
# </table>
#
#
# </ul>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>What You Will Do in This Notebook</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# This notebook is designed to guide you through a comprehensive set of exercises focused on working with content-based Vector Store and ask APIs. By the end of this tutorial, you will have gained hands-on experience with creating content-based vector store objects as well as asking questions and performing similarity searches. Here's what you'll learn:
# </p>
#
# <div style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <ol>
# <li>
# <b>Installing latest teradatagenai</b>
# </li>
# <li>
# <b>Creating a new Content-Based Vector Store</b>
# </li>
# <li>
# <b>Using existing Vector Store</b>
# </li>
# <li>
# <b>Updating Vector Store</b>
# </li>
# <li>
# <b>Performing Similarity Seach and Asking questions</b>
# </li>
# <li>
# <b>Destroying Vector Store</b>
# </li>
# </ol>
# </div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Installing latest teradatagenai</b>

# %%
# %pip install teradatagenai

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Import necessary modules</b>

# %%
import os
from getpass import getpass
# Required imports
from teradatagenai import VSManager, VectorStore, VSPattern, VSApi, TeradataAI, TextAnalyticsAI, load_data
from teradataml import create_context, set_auth_token, DataFrame, in_schema, remove_context

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:20px;font-family:Arial;color:#00233C'>Connect to Vantage</b>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the details to create the connection to Vantage. Enter the details, press the Enter key, then use down arrow to go to next cell. Begin running steps with Shift + Enter keys.</p>

# %%
os.environ['TD_HOST'] = getpass(prompt='hostname: ')
os.environ['TD_USERNAME'] = getpass(prompt='username: ')
os.environ['TD_PASSWORD'] = getpass(prompt='password: ')
os.environ['TD_BASE_URL'] = getpass(prompt='base_url: ')
os.environ['TD_PAT_TOKEN'] = getpass(prompt='pat_token: ')
os.environ['TD_PEM_FILE'] = getpass(prompt='pem_file: ')
create_context()
# Out:
# Authentication token is generated, authenticated and set for the session.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <b style = 'font-size:30px;font-family:Arial;color:#00233C'>1. Getting Started with Vector Store </b>

# %% [markdown]
# ### 🛠 Steps to Create a Vector Store
#
# 1. **Initialize a VectorStore Instance**
#    - Create an instance of `VectorStore`
#
# 2. **Create the Vector Store**
#    - Use the `create()` method on the vector store instance to create a new vector store.
#
# By following these steps, we will successfully create vector store - `vs_example`.

# %%
vs = VectorStore(name="vs_example", log=True)

# %%
# Create an input DataFrame as amazon_reviews_25 is in 'oaf' database.
input_data = DataFrame(in_schema('oaf', 'amazon_reviews_25'))

# %%
# Python
vs.create(object_names= input_data,
          key_columns= ['rev_id', 'aid'],
          data_columns= ['rev_text'],
          metadata_columns= ['prodsummary', 'rev_name'],
          vector_column= 'VectorIndex',
          embeddings_model= 'amazon.titan-embed-text-v1',
          search_algorithm= 'KMEANS',
          seed=10,
          top_k=10)
# Out:
# Vector store vs_example creation started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### ✅ Checking the Status of the Vector Store
#
# Though the create, update, destroy APIs are synchronous and will complete only after the operation is complete, user can ensure the same using the **status** API.
#
#  **Check the `status`**
#    - The `status` function allows you to confirm whether the particular operation is successful.

# %% [markdown]
# #### In this example, we can see the status of creation using **status()**

# %%
vs.status()
# Out:
#       vs_name status
# 0  vs_example  READY

# %% [markdown]
# ### Check the type of vector store using `store_type` parameter.

# %%
vs.store_type
# Out:
# 'content-based'

# %% [markdown]
# #### Get the details of the Vector Store.

# %%
vs.get_details()
# Out:
#       vs_name     store_type description database_name  sample_size            embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold  search_numcluster ef_search initial_centroids_method  train_numcluster  max_iternum  stop_threshold  seed  num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects               document_objects document_columns   document_indexes prompt vector_column                   chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status base_url_embeddings base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated                                                                       metadata_columns base_url_content_safety base_url_topic_control base_url_jailbreak_detection content_safety_model topic_control_model guardrails num_NodesPerGraph onnx_model_table onnx_tokenizer_table onnx_model_id onnx_tokenizer_id onnx_model_column onnx_tokenizer_column onnx_model_id_column onnx_tokenizer_id_column embedding_datatype  use_simd base_url_vlm vlm_model  maximal_marginal_relevance  lambda_multiplier permission
# 0  vs_example  content-based        None           OAF           20  amazon.titan-embed-text-v1             1536  COSINE           KMEANS     10             None                  1      None                   RANDOM                 5           10          0.0395    10         1      None            None            None               None             None             None             None            None            None  ["\"oaf\".amazon_reviews_25"]     ["rev_text"]  ["rev_id", "aid"]   None   VectorIndex  anthropic.claude-3-haiku-20240307-v1:0            0.2                       None               60                        4096     READY                None                 None            None             None          None            None       None             None               None        None          None                None  2025-09-17 21:54:55.198676+00:00  [{"name": "prodsummary", "description": ""}, {"name": "rev_name", "description": ""}]                    None                   None                         None                 None                None       None              None             None                 None          None              None              None                  None                 None                     None           VECTOR32         0         None      None                           0                0.5      ADMIN

# %% [markdown]
# #### Use the get_indexes_embeddings function to get the vector store which is created internally.

# %%
output = vs.get_indexes_embeddings()

# %%
output.head(1)
# Out:
#   DataBaseName          TableName         rev_id         aid                            prodsummary    rev_name                                                                                                              rev_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       VectorIndex                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            VectorIndex_normalized  clusterID
# 0          oaf  amazon_reviews_25  AUTNO7VDY4H4A  000100039X  A great book, buying it for a friend.  Austin guy  Loved this book since first I read it, years gone by. Purchased this copy for a friend who has not ever read Gibran.          25  -0.6171875,0.09912109375,-0.3515625,0.18359375,0.08740234375,-0.08544921875,-0.4296875,0.00031280517578125,-0.4765625,0.2890625,-0.203125,0.1806640625,-0.29296875,0.30078125,0.255859375,0.25390625,-0.0693359375,-0.62890625,-0.0439453125,-0.263671875,-0.2421875,-0.1484375,-0.119140625,1.1328125,-0.07421875,0.0810546875,0.4453125,-1,0.05126953125,-0.99609375,0.51953125,1.265625,-0.400390625,-0.5078125,0.8046875,0.0732421875,0.53125,-1.1328125,0.6015625,0.1396484375,-0.025146484375,-0.19140625,-0.54296875,-0.09326171875,0.6953125,-0.373046875,0.3203125,-0.1923828125,0.326171875,-0.00518798828125,-0.01531982421875,-0.333984375,1.7578125,-0.09716796875,-0.140625,0.166015625,0.2080078125,-0.26171875,-0.71484375
#       vs_name     store_type description database_name  sample_size            embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold  search_numcluster ef_search initial_centroids_method  train_numcluster  max_iternum  stop_threshold  seed  num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects               document_objects document_columns   document_indexes prompt vector_column                   chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status base_url_embeddings base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated                              metadata_columns base_url_content_safety base_url_topic_control base_url_jailbreak_detection content_safety_model topic_control_model guardrails num_NodesPerGraph onnx_model_table onnx_tokenizer_table onnx_model_id onnx_tokenizer_id onnx_model_column onnx_tokenizer_column onnx_model_id_column onnx_tokenizer_id_column embedding_datatype  use_simd base_url_vlm vlm_model  maximal_marginal_relevance  lambda_multiplier permission
# 0  vs_example  content-based        None           OAF           20  amazon.titan-embed-text-v1             1536  COSINE           KMEANS     10             None                  1      None                   RANDOM                 5           10          0.0395    10         1      None            None            None               None             None             None             None            None            None  ["\"oaf\".amazon_reviews_25"]     ["rev_text"]  ["rev_id", "aid"]   None   VectorIndex  anthropic.claude-3-haiku-20240307-v1:0            0.2                       None               60                        4096     READY                None                 None            None             None          None            None       None             None               None        None          None                None  2025-09-17 21:57:27.396226+00:00  [{"name": "prodsummary", "description": ""}]                    None                   None                         None                 None                None       None              None             None                 None          None              None              None                  None                 None                     None           VECTOR32         0         None      None                           0                0.5      ADMIN

# %% [markdown]
# ### 🔍 Performing Similarity Search.
#
# \**similarity search** allows us to find the most relevant vectors based on a given input. By passing a question to the vector store `vs_example`, we can retrieve the closest matches based on the selected search algorithm.
#
# #### 🛠 How It Works
#
# 1. **Input a question**
#    - Pass a question or input text to `question` argument of `similarity_search()`.
#
# 2. **Perform the Similarity Search**
#    - The vector store searches for the most relevant matches using the specified **`search_algorithm`**.
#
# 3. **Retrieve Top Matches**
#    - The result contains the **top_k** most relevant entries along with their similarity scores, helping us understand how closely they match the input.
#
# This process enables efficient retrieval of information based on vector embeddings, making it useful for applications such as **semantic search, recommendation systems, and document retrieval**. 🚀

# %%
question = 'Which book are all the reviews talking about?'
response = vs.similarity_search(question=question, top_k=6)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                              prodsummary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                rev_text  index_label
# 0  0.369028          oaf  amazon_reviews_25  A1TT4CY55WLHAR  000100039X  textured paper, old-style typography, and leather cover                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I have the 1972 version, bought in 1974. The 1972 version originally had a dust jacket but my dust jacket is long gone. This particular rendition has had many re-printings, for a reason: it\'s very popular. The textured paper, old-style typography, and leather cover are better than a plain-old paperback. The size is diminutive, which is perfect for this book.            2
# 1  0.363585          oaf  amazon_reviews_25   ARDQ9KNB8K22N  000100039X                                  ""The Prophet"" is cool  Cool book, I really like the quality of the production. Black clothbound with gold embossing and nice paper, looks to be cotton rag. I am proud to include it in my collection. Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life. The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus. I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter. Excellent for busy people or commuters!            4
# 2  0.349094          oaf  amazon_reviews_25  A2S166WSCFIFP5  000100039X                                             close to god                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          This is one my must have books. It is a masterpiece of spirituality. I\'ll be the first to admit, its literary quality isn\'t much. It is rather simplistically written, but the message behind it is so powerful that you have to read it. It will take you to enlightenment.            5
# 3  0.363597          oaf  amazon_reviews_25  A1KQ80Y692CDOI  000100039X                                                 Eloquent                                                                                                                                                                                                                                                                                I read this about a year ago and can\'t recall a great deal of the book. From what I do recall it was like a poem all the way through. While the writing was beautiful, I found it ambiguous and befuddled with meaning that I could not identify with. When Gibran speaks of God, I cannot identify because I have since abandoned those philosophies. It is thus difficult to revisit them in this book. I have the feeling I may have missed something great about this book. Indeed, I pulled wisdom from parts, but rather than go back and read it again, for now, perhaps I will move on to another of the many books out there that are enlightening and worth reading. Someday, I would like to read this again and dig deeper.            3
# 4  0.393761          oaf  amazon_reviews_25  A1340OFLZBW5NG  000100039X          Perhaps the greatest book that I have ever read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it..            1
# 5  0.432340          oaf  amazon_reviews_25   AENNW2G826191  000100039X                                                Good Read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the author, it has to be consumed slowly and perhaps revisited but leaves you pretty heady and clear about certain things.            0

# %% [markdown]
# ### 📝 Generating a Natural Language Response
#
# Once the **`similarity_search()`** method retrieves relevant results from the vector store, we can generate a natural language response by proving a prompt..
#
# #### 🛠 Steps to Prepare the Response
# 1.  **Input a question**
#    - Pass a question or input text to `question` argument of `prepare_response()`.
#
# 1. **Retrieve Similarity Results**
#    - The `similarity_search()` method returns the most relevant matches along with their similarity scores.
#
# 3. **Input a prompt**
#    - By passing `prompt`, we ask the model to format the output in a particular way
#
# #### As we can see below, by passing the question and the prompt, the response is formated in a conversational manner as suggested in the prompt.

# %%
question='Did any one feel the book is thin?'
prompt='Format the response in a conversational way.'
response = vs.prepare_response(question=question, similarity_results=response, prompt=prompt)

# %%
print(response)
# Out:
# Based on the reviews, it seems that some readers did feel the book "The Prophet" by Kahlil Gibran is a thin book, but they still found it to be impactful and meaningful. Here are a few relevant excerpts:
#
# "Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading."
#
# "The size is diminutive, which is perfect for this book."
#
# "Cool book, I really like the quality of the production. Black clothbound with gold embossing and nice paper, looks to be cotton rag. I am proud to include it in my collection. Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed."
#
# So while some reviewers noted the book's thin or diminutive size, they still seemed to appreciate the concise and impactful nature of the content, as well as the high quality of the physical book itself. The thinness of the book did not detract from its value for these readers.

# %% [markdown]
# ### ⚡ ask:
# #### Unified Similarity Search & Response Generation
# To improve efficiency, we can **combine similarity search and response generation** into a single operation. This method performs a similarity search in the vector store using the **input query** and then prepares a natural language response based on the retrieved results.
#
# #### 🔍 How It Works
#
# 1.  **Input a question**
#    - Pass a question or input text to `question` argument of `ask()`.
#
# 3. **Input a prompt**
#    - By passing `prompt`, we ask the model to format the output in a particular way
#
# **Faster Execution**
#    - By combining both steps into a single function call, response time is reduced, making the system more efficient.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
Review ID: 
Author ID: 
Review: 
"""
question ='Are there any reviews saying that the books are inspiring?'
response = vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are several reviews that describe the book as inspiring:
#
# Review ID: A10000012B7CGYKOMPQ4L
# Author ID: 000100039X
# Review: Spiritually and mentally inspiring! A book that allows you to question your morals and will help you discover who you really are!
#
# Review ID: A2S166WSCFIFP5
# Author ID: 000100039X
# Review: This is one my must have books. It is a masterpiece of spirituality. It will take you to enlightenment.
#
# Review ID: A1MOSTXNIO5MPJ
# Author ID: 000100039X
# Review: Gibran offers timeless insights and love with each word. I think that we as a nation should read AND learn the lessons here. It is definitely a time for thought and reflection this book could guide us through.

# %%
VSManager.disconnect()
# Out:
# Database connection closed.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
#
# <b style="font-size:30px; font-family:Arial; color:#00233C;">2. Initializing and Using the Existing Vector Store</b>

# %% [markdown]
# ### 🔄 Using an Existing Vector Store
#
# If you have an existing vector store that you want to reuse, you can initialize it by providing the **name** of the store. This allows you to interact with and perform operations on the existing store without creating a new one.
#
# #### 🛠 Steps to Initialize existing Vector Store
#
# 1. **Provide the Name of the Vector Store**
#    - Specify the name (e.g., `vs_example`) of the existing vector store that you want to access.
#
#
# 2. **Initialize the Vector Store Instance**
#    - By using the provided name, you can initialize the vector store instance and begin interacting with it.

# %%
# Initialize existing VS
updated_vs = VectorStore("vs_example")
# Out:
# Vector store vs_example is initialized.

# %% [markdown]
# ### ✨ Updating Arguments of an Existing Vector Store
#
# You can **update** specific parameters of an existing vector store without having to recreate it. For instance, you may want to modify the **search algorithm** or other configuration settings to better suit your needs. This can be done using the `update()` API, which allows you to change the arguments of the vector store.
#
# #### 🛠 Steps to Update an Existing Vector Store
#
# 1. **Access the Existing Vector Store**
#    - First, ensure that the vector store (e.g., `vs_update`) is already initialized.
#
# 2. **Use the `update()` API**
#    - Call the `update()` method on the vector store instance and provide the new argument(s) you want to modify, such as the `search_algorithm`.

# %%
updated_vs.update(search_algorithm="KMEANS")
# Out:
# Vector store vs_example update started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
#       vs_name status
# 0  vs_example  READY

# %% [markdown]
# ### ✨ Updating Data of an Existing Vector Store
#
# You can **add** or **delete** data in a Vector Store.
#
# #### 🛠 Steps to Update an Existing Vector Store
#
# 1. **Access the Existing Vector Store**
#    - First, ensure that the vector store (e.g., `vs_update`) is already initialized.
#
# 2. **Use the `update()` API**
#    - Call the `update()` method on the vector store instance and provide the new argument(s).

# %%
# Create a new table with the contents to add to the Vector Store. 
# Make sure this table has the columns which are used as data_columns, key_columns and metadata_columns in existing Vector Store.
import pandas as pd
from teradataml import copy_to_sql
from teradatasqlalchemy import VARCHAR
df = {'prod_name': ['A1', 'A2', 'A3', 'A4'],
      'rev_id': ['100', '200', '300', '400'],
      'rev_text': ['Product is good', 'quality is bad', 'needs improvement', 'Bad quality'],
      'aid': ['99.99', '97.32', '94.67', '91.00'],
      'prodsummary': ['Good product', 'Bad product', 'Average product', 'Poor product']
      }
pandas_df = pd.DataFrame(df)
copy_to_sql(df=pandas_df, table_name='test_table_update',
            if_exists='replace',
            types={'rev_text': VARCHAR(64000)})

# %%
updated_vs.update(object_names='test_table_update',
                  alter_operation="ADD",
                  update_style="MINOR")
# Out:
# Vector store vs_example update started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
#       vs_name status
# 0  vs_example  READY

# %%
op = updated_vs.get_indexes_embeddings()

# %%
op.loc[op['TableName'] == 'test_table_update']
# Out:
#   DataBaseName          TableName rev_id    aid      prodsummary           rev_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       VectorIndex                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            VectorIndex_normalized  clusterID
# 0          OAF  test_table_update    100  99.99     Good product    Product is good          26  0.73046875,-0.1318359375,0.2041015625,0.15625,0.357421875,0.00048828125,-0.1572265625,-0.000394821166992188,-0.123046875,0.55078125,-0.08203125,1.234375,0.1181640625,-0.2255859375,0.09033203125,0.35546875,-0.158203125,-0.490234375,-0.09033203125,-0.24609375,-0.43359375,0.1875,-0.47265625,0.52734375,0.0164794921875,-0.4375,-0.56640625,-1.0859375,-0.486328125,-0.150390625,0.78125,1.0546875,-0.1064453125,-0.23828125,0.447265625,0.06494140625,0.416015625,-0.96484375,0.5546875,-0.1884765625,1.1171875,0.2265625,0.361328125,0.0908203125,1.1953125,-0.8828125,0.0269775390625,0.20703125,0.07958984375,0.9453125,0.224609375,-0.0712890625,0.91015625,-0.2578125,0.345703125,-0.224609375,-0.2060546875,0.123046875,-0.76171875,0.2001953125,1.109375,0.38671875,-0.19921875,0.291015625,0.0634765625,-0.2060546875,-0.53515625,0.1484375,-0.01513671875,-0.006683349609375,-0.1767578125,0.287109375,-0.72265625,-1.1875,1.296875,-0.1484375,0.1787109375,-0.2333984375,0.65234375,0.69921875,-0.087890625,1.0546875,-0.5078125,1.25,0.400390625  0.0410020872950554,-0.0074001089669764,0.0114564653486013,0.00877049937844276,0.020062517374754,2.74078120128252e-05,-0.00882531516253948,-2.21617847273592e-05,-0.00690676830708981,0.0309160109609365,-0.00460451235994697,0.0692869499325752,0.00663269031792879,-0.0126624088734388,0.00507044512778521,0.0199528876692057,-0.0088801309466362,-0.0275174435228109,-0.00507044512778521,-0.0138135366141796,-0.024338137358427,0.0105245998129249,-0.0265307612717152,0.0296004358679056,0.000925013620872051,-0.0245573986321688,-0.0317930616438389,-0.0609549731016159,-0.0272981803864241,-0.00844160560518503,0.0438524968922138,0.0592008717358112,-0.00597490277141333,-0.013375012204051,0.0251055546104908,0.00364523893222213,0.0233514551073313,-0.0541578345000744,0.0311352740973234,-0.0105794155970216,0.0627090707421303,0.0127172246575356,0.0202817805111408,0.00509785301983356,0.0670943260192871,-0.0495533235371113,0.0015142816118896,0.0116209117695689,0.00446747336536646,0.0530615225434303,0.0126075930893421,-0.004001540597528          3
00189259427133948,-0.013060980476439,0.00948376953601837,-0.000519943481776863,-0.00665527675300837,-0.0262883435934782,0.0178028661757708,-0.033110000193119,-0.0051162438467145,-0.00280769495293498,0.0515783950686455,-0.00698804063722491,-0.0319453291594982,-0.0142256543040276,-0.0112307798117399,-0.0555715598165989,-0.0129777900874615,0.040929950773716,0.0469196997582912,0.0201322119683027,0.00665527675300837,-0.00549060339108109,-0.00228775129653513,0.0420946255326271,-0.0299487449228764,-0.00673846760764718,0.00255812192335725,0.0479179918766022,0.0595647282898426,0.0131441717967391,0.0167213827371597,0.0282849259674549,-0.0725425183773041,-0.000431553111411631,-0.00386837963014841,-0.00948376953601837,0.0174701008945704,0.0171373374760151,-0.00503305299          3

# %% [markdown]
# ### Delete contents of 'test_table_update' from Vector Store.

# %%
updated_vs.update(object_names='test_table_update',
                  alter_operation="DELETE",
                  update_style="MINOR")
# Out:
# Vector store vs_example update started.
# Use the 'status()' api to check the status of the operation.

# %%
updated_vs.status()
# Out:
#       vs_name status
# 0  vs_example  READY

# %%
op = updated_vs.get_indexes_embeddings()

# %%
op.head(2)
# Out:
#   DataBaseName          TableName          rev_id         aid                      prodsummary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     rev_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       VectorIndex                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            VectorIndex_normalized  clusterID
# 0          oaf  amazon_reviews_25  A19N3FCQCLJYUA  000100039X  A book everyone ""should"" read  I discovered The Prophet fifty years ago in college and have read it dozens of times since then. Now, in addition to my beat up hard copy, I have a portable e-copy. If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it. It doesn\'t care how you picture, name or define ""God"" or whether you give him a gender and a personality. It just cuts to the heart of how to live and how to relate to others. If Jesus and the Buddha teamed up to write a book, it might come out like this. When I first read it, I found some passages difficult to grasp. Looking back, I now think that it was not because they were hard to understand, but because I did not want to hear gently spoken, intelligently phrased ideas that contradicted my own. Now, if I could have only one book, this would probably be it.           4  -0.271484375,0.1455078125,0.171875,-0.058349609375,-0.2392578125,-0.13671875,-0.1611328125,0.000436782836914062,-0.04833984375,0.03173828125,0.006072998046875,0.041259765625,-0.142578125,0.2578125,-0.0223388671875,0.099609375,-0.042724609375,-0.1962890625,-0.185546875,-0.185546875,0.003997802734375,0.0380859375,-0.0654296875,0.48828125,0.2890625,-0.171875,0.458984375,-0.345703125,-0.138671875,-0.435546875,0.255859375,0.263671875,-0.06298828125,-0.55078125,0.41796875,0.158203125,0.53125,-0.69140625,0.765625,-0.0341796875,0.1591796875,-0.042236328125,-0.25390625,-0.037109375,0.203125,-0.294921875,0.12353515625,-0.1533203125,0.1884765625,0.224609375,0.310546875,0.130859375,0.859375,0.138671875,-0.10498046875,-0.482421875,0.044677734375,-0.169921875,-0.3671875,0.2431640625,0.341796875,0.291015625,0.09716796875,0.19921875,0.1494140625,0.330078125,-0.173828125,0.28125,-0.040771484375,0.06884765625,-0.07275390625,-0.06103515625,-0.33984375,-0.5390625,0.0625,-0.0179443359375,-0.166015625,-0.03173828125,0.12060546875,  -0.0275108851492405,0.0147450426593423,0.0174169633537531,-0.00591286085546017,-0.0242452044039965,-0.0138544021174312,-0.0163284037262201,4.
-0.0323592238128185,0.0242694169282913,0.060243234038353,-0.0150608085095882,-0.039932657033205,0.031670730561018,0.0139420060440898,0.0418260172009468,-0.0592104941606522,0.0547352805733681,0.0131674502044916,-0.0342525839805603,-0.0139420060440898,-0.0409654006361961,-0.00753040425479412,0.000839102198369801,-0.0242694169282913,0.00821889843791723,-0.0297773703932762,0.0104565043002367,0.0154911177232862,-0.00199017836712301,0.02426941692829          1

# %%
op.loc[op['TableName'] == 'test_table_update']
# Out:
# Empty DataFrame
# Columns: [DataBaseName, TableName, rev_id, aid, prodsummary, rev_text, TD_TEMP_ID, VectorIndex, VectorIndex_normalized, clusterID]
# Index: []

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Asking on the Updated Vector Store
#
# Once you've updated the vector store, you can seamlessly perform a **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.
#
# #### 🛠 Steps to Perform on the Updated Vector Store
#
# 1. **Similarity Search**
#    - Use the `similarity_search()` method to find the most relevant matches for your input question based on the updated configuration.

# %%
question = 'Which book are all the reviews talking about?'
response = updated_vs.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                                              prodsummary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                rev_text  index_label
# 0  0.369028          oaf  amazon_reviews_25  A1TT4CY55WLHAR  000100039X  textured paper, old-style typography, and leather cover                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I have the 1972 version, bought in 1974. The 1972 version originally had a dust jacket but my dust jacket is long gone. This particular rendition has had many re-printings, for a reason: it\'s very popular. The textured paper, old-style typography, and leather cover are better than a plain-old paperback. The size is diminutive, which is perfect for this book.            2
# 1  0.363585          oaf  amazon_reviews_25   ARDQ9KNB8K22N  000100039X                                  ""The Prophet"" is cool  Cool book, I really like the quality of the production. Black clothbound with gold embossing and nice paper, looks to be cotton rag. I am proud to include it in my collection. Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life. The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus. I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter. Excellent for busy people or commuters!            4
# 2  0.349094          oaf  amazon_reviews_25  A2S166WSCFIFP5  000100039X                                             close to god                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          This is one my must have books. It is a masterpiece of spirituality. I\'ll be the first to admit, its literary quality isn\'t much. It is rather simplistically written, but the message behind it is so powerful that you have to read it. It will take you to enlightenment.            5
# 3  0.336766          oaf  amazon_reviews_25   AUTNO7VDY4H4A  000100039X                    A great book, buying it for a friend.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Loved this book since first I read it, years gone by. Purchased this copy for a friend who has not ever read Gibran.            6
# 4  0.315819          oaf  amazon_reviews_25  A3FFNE1DR5SI1W  000100039X                          phenomenal piece of literature!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Can\'t say enough about Kahlil Gibran\'s work among this piece. Everybody in the whole world should read this! There is almost too much to take in, really appreciate and put towards our daily lives. In my opinion, it is just one of the most beautiful literature pieces ever written. Would recommend to as a gift for anyone spiritual/poetic/philosophy/educational piece or just something to enjoy here and there. 5 stars for sure!            8
# 5  0.273120          oaf  amazon_reviews_25  A3FI0744PG1WYG  000100039X                                              The Prophet                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is a timeless classic. Over the years I\'ve given it as a gift more times than I can count, and will continue to do so. Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives. So easy to read over and over.            9
# 6  0.321833          oaf  amazon_reviews_25  A26GKZPS079GFF  000100039X                  Touches my heart.. again and.. again...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I would have to say that this is the best book I\'ve ever read.. I could feel every word deep in my heart everytime, of the many times I\'ve read it! I would never get enough of it! its a treasure..            7
# 7  0.363597          oaf  amazon_reviews_25  A1KQ80Y692CDOI  000100039X                                                 Eloquent                                                                                                                                                                                                                                                                                I read this about a year ago and can\'t recall a great deal of the book. From what I do recall it was like a poem all the way through. While the writing was beautiful, I found it ambiguous and befuddled with meaning that I could not identify with. When Gibran speaks of God, I cannot identify because I have since abandoned those philosophies. It is thus difficult to revisit them in this book. I have the feeling I may have missed something great about this book. Indeed, I pulled wisdom from parts, but rather than go back and read it again, for now, perhaps I will move on to another of the many books out there that are enlightening and worth reading. Someday, I would like to read this again and dig deeper.            3
# 8  0.393761          oaf  amazon_reviews_25  A1340OFLZBW5NG  000100039X          Perhaps the greatest book that I have ever read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I LOVE this book... his writing seems to just flow from page to page. I get something different from this book each time I read it..            1
# 9  0.432340          oaf  amazon_reviews_25   AENNW2G826191  000100039X                                                Good Read                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the author, it has to be consumed slowly and perhaps revisited but leaves you pretty heady and clear about certain things.            0

# %% [markdown]
# 2. **Prepare the Response**
#    - After retrieving the search results, use the `prepare_response()` function to generate a user-friendly, natural language response based on the most relevant matches.

# %%
question = 'Which book are all the reviews talking about?'
response = updated_vs.prepare_response(question=question, similarity_results=response)

# %%
print(response)
# Out:
# The book all the reviews are talking about is "The Prophet" by Kahlil Gibran.

# %% [markdown]
# 3. **Ask the Updated Vector Store**
#    - Combine these operations using the `ask()` method, which performs the search and generates the response in one call, ensuring faster and more efficient retrieval of information.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = updated_vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are several reviews that mention the book as inspiring. Here are a few examples:
#
# review_id: 0
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: Anything I've read by Gibran is, in my mind, flawless. This, the most famous of his works, is no exception. It is simple, yet deep; honest and profound; moving and inspirational. Gibran's work is one of a kind, and can be far more encouraging and moving than any self-help program or therapy or anything like that.
#
# review_id: 2
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: For those who don't know Gibran, get to know his work. The Prophet is a must read. His outlook on life is truly an inspiring guide on how to approach major life decisions.
#
# review_id: 3
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: If you were looking for an example of an intelligently designed (pun intended) book of spiritual guidance, this would be it. It doesn't care how you picture, name or define "God" or whether you give him a gender and a personality. It just cuts to the heart of how to live and how to relate to others. If Jesus and the Buddha teamed up to write a book, it might come out like this.
#
# review_id: 4
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: You see, if you have ideas and you do not realize them, then they are nothing, and if your ideas do not come from love and joy, then they are bitter and what they produce will be bitter, but if they flow from love and joy, then their realization will be love and joy, thus work is love made visible. He says it WAY better that I do and says much more in just a few paragraphs. But as you can see from the example, what he says is not religious, but positive ways of looking at things.
#
# review_id: 5
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: Can't say enough about Kahlil Gibran's work among this piece. Everybody in the whole world should read this! There is almost too much to take in, really appreciate and put towards our daily lives. In my opinion, it is just one of the most beautiful literature pieces ever written.
#
# review_id: 6
# Book Title: The Prophet
# Author: Kahlil Gibran
# Review: As you read, Gibran's poetry brings spiritual and visual beauty to life within you. Gibran is justly famous for rich metaphors that brilliantly highlight the pursuit of Truth and Goodness amidst all the darkness and light of human nature.

# %%
updated_vs.destroy()
# Out:
# Vector store vs_example destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### 🛠 Instantiating a Content Based Vector Store using `from_datasets` method.
#
# We can also create an instance of a content-based Vector Store directly using the `from_datasets` of the VectorStore class.
#
# **from_datasets()**
#    - Creates a new 'content-based' vector store from the input dataset(s) containing table(s) or teradataml DataFrames(s).
#    - `name` , `data` and `data_columns` are mandatory arguments and we can also provide other arguments related to creation and search metrics.
#
#
# Below examples show how we can create content-based stores using these methods

# %%
# Loading example data
load_data('byom', 'amazon_reviews_10')
amazon_reviews_updated = DataFrame('amazon_reviews_10')
# Out:
# WARNING: Skipped loading table amazon_reviews_25 since it already exists in the database.
# WARNING: Skipped loading table amazon_reviews_10 since it already exists in the database.

# %%
# Creating an instance of VectorStore using from_datasets() method
vs_instance_dataset = VectorStore.from_datasets(name = "vs_example_from_datasets",
                                                data = input_data,
                                                data_columns = "rev_text",
                                                metadata_columns = ["rev_name"],
                                                key_columns = ["rev_id", "aid"],
                                                embedding = "amazon.titan-embed-text-v2:0")
# Out:
# Vector store vs_example_from_datasets creation started.
# Use the 'status()' api to check the status of the operation.

# %%
# Check status of the store
vs_instance_dataset.status()
# Out:
#                     vs_name status
# 0  vs_example_from_datasets  READY

# %% [markdown]
# ### ✨ Adding and Deleting datasets
#
# You can **add** or **delete** datasets from an existing Vector Store using the `add_datasets()` and `delete_datasests()` methods.
#
# Note: Deleting datasets only works if the VectorStore is initialized using `key_columns`

# %%
vs_instance_dataset.add_datasets(data=amazon_reviews_updated)
# Out:
# Vector store vs_example_from_datasets update started.
# Use the 'status()' api to check the status of the operation.

# %%
# Check the status of the updated store.
vs_instance_dataset.status()
# Out:
#                     vs_name status
# 0  vs_example_from_datasets  READY

# %%
vs_instance_dataset.delete_datasets(data=amazon_reviews_updated)
# Out:
# Vector store vs_example_from_datasets update started.
# Use the 'status()' api to check the status of the operation.

# %%
# Check the status of the updated store.
vs_instance_dataset.status()
# Out:
#                     vs_name status
# 0  vs_example_from_datasets  READY

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Ask
#
# Using the vector store instance, you can do **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.
#
# #### 🛠 Steps to Perform on the Updated Vector Store
#
# 1. **Similarity Search**
#    - Use the `similarity_search()` method to find the most relevant matches for your input question based on the updated configuration.

# %%
question = 'Positive reviews about the books'
response = vs_instance_dataset.similarity_search(question=question, search_threshold = 0.1)

# %%
response.similar_objects
# Out:
#       score DataBaseName          TableName          rev_id         aid                     rev_name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                rev_text  index_label
# 0  0.168957          oaf  amazon_reviews_25  A2KU9IU07LOJS1  000100039X              Amazon Customer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         This book has been a classic for many years. It has so much wisdom in it that it can be read numerous times and new things will come out each time. My favorite chapter is the one on children.            2
# 1  0.158057          oaf  amazon_reviews_25  A2XQ5LZHTD4AFT  000100039X                     Alaturka                                                                                                                                                                                 A timeless classic. It is a very demanding and assuming title, but Gibran backs it up with some excellent style and content. If he had the means to publish it a century or two earlier, he could have inspired a new religion. From the mouth of an old man about to sail away to a far away destination, we hear the wisdom of life and all important aspects of it. It is a message. A guide book. A Sufi sermon. Much is put in perspective without any hint of a dogma. There is much that hints at his birthplace, Lebanon where many of the old prophets walked the Earth and where this book project first germinated most likely. Probably because it was written in English originally, the writing flows, it is pleasant to read, and the charcoal drawings of the author decorating the pages is a plus. I loved the cover.            4
# 2  0.157980          oaf  amazon_reviews_25   AENNW2G826191  000100039X                     Ashish A                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Its a thin book, very readable and has interesting 1-2 page thoughts on various entities like anger, children, religion, speech, silence and its COOL.........reading. Ofcourse if one needs to imbibe the thoughts of the author, it has to be consumed slowly and perhaps revisited but leaves you pretty heady and clear about certain things.            5
# 3  0.155491          oaf  amazon_reviews_25   A27ZH1AQORJ1L  000100039X  anybody else or ""amanuet""                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              This book is everything that is simple, delicate, true, and beautiful. I have read few books so touching and enlightening; &quot;The Prophet&quot; is a true masterpiece that has that feeling of ancient wisdom in it. The wisdom of the text is gentle, yet insistent, it lets you understand things you\'ve always known. My feelings defy description.            6
# 4  0.151947          oaf  amazon_reviews_25   ARDQ9KNB8K22N  000100039X                        Anwar  Cool book, I really like the quality of the production. Black clothbound with gold embossing and nice paper, looks to be cotton rag. I am proud to include it in my collection. Intrigueing story full of the sort of passion that does not cloud the mind or divert truth but instead is revealing and living. Very readable, the stories are short and highly economic so that one is likely to read for only a minute or two until something insightful is revealed. It is full of timeless truths which are of lasting value to the reader and inform life. The language and delivery is familiar yet of a quality that is penetrating in a similar way as it might be listening to a surmon by Jesus. I give it 5 stars. I considered giving only 4 stars because the format is fairly predictable but I have decided that this quality is actually a strength as one can pick up the book at any point and continue until the end...and then start over for that matter. Excellent for busy people or commuters!            8
# 5  0.151469          oaf  amazon_reviews_25  A3FI0744PG1WYG  000100039X       Always Reading ""tkm""                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           This is a timeless classic. Over the years I\'ve given it as a gift more times than I can count, and will continue to do so. Addresses real life issues in a beautiful way and makes us reexamine our own attitude about how we see what happens in our lives. So easy to read over and over.            9
# 6  0.152257          oaf  amazon_reviews_25   AUTNO7VDY4H4A  000100039X                   Austin guy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Loved this book since first I read it, years gone by. Purchased this copy for a friend who has not ever read Gibran.            7
# 7  0.158493          oaf  amazon_reviews_25  A26GKZPS079GFF  000100039X                        Areej                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I would have to say that this is the best book I\'ve ever read.. I could feel every word deep in my heart everytime, of the many times I\'ve read it! I would never get enough of it! its a treasure..            3
# 8  0.175386          oaf  amazon_reviews_25  A3FFNE1DR5SI1W  000100039X                   A. Morelli                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Can\'t say enough about Kahlil Gibran\'s work among this piece. Everybody in the whole world should read this! There is almost too much to take in, really appreciate and put towards our daily lives. In my opinion, it is just one of the most beautiful literature pieces ever written. Would recommend to as a gift for anyone spiritual/poetic/philosophy/educational piece or just something to enjoy here and there. 5 stars for sure!            1
# 9  0.178841          oaf  amazon_reviews_25  A2WVHIRDMLM82E  000100039X              Amazon Customer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               This book has so much you can take out of it to use in your real life. Amazing, and one of my favorite reads of all time.            0

# %% [markdown]
# 2. **Prepare the Response**
#    - After retrieving the search results, use the `prepare_response()` function to generate a user-friendly, natural language response based on the most relevant matches.

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_dataset.prepare_response(question=question, similarity_results=response)
print(response)
# Out:
# Based on the information provided in the reviews, the book being discussed is "The Prophet" by Kahlil Gibran. The reviews consistently mention Kahlil Gibran as the author and refer to the content and themes of his famous work "The Prophet".

# %% [markdown]
# 3. **Ask the Updated Vector Store**
#    - Combine these operations using the `ask()` method, which performs the search and generates the response in one call, ensuring faster and more efficient retrieval of information.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = vs_instance_dataset.ask(question=question, prompt=custom_prompt)

# %%
# Destroy the Vector Store instance
vs_instance_dataset.destroy()
# Out:
# Vector store vs_example_from_datasets destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### 🛠 Using TeradataAI object for embedding and chat models
# - You can also use TeradataAI objects as embedding and chat completion model input to the Vector Store during initialization.
# - The below example initialized two TeradataAI objects, one for embedding and one for chat model and initializes the store using the `from_datasets` method.

# %%
import os
# Initialize the TeradataAI object using environment variables.
os.environ["AWS_DEFAULT_REGION"] = "<Enter AWS Region>"
os.environ["AWS_ACCESS_KEY_ID"] = "<Enter AWS Access Key ID>"
os.environ["AWS_SECRET_ACCESS_KEY"] = "<Enter AWS Secret Key>"
os.environ["AWS_SESSION_TOKEN"] = "<Enter AWS Session key>"
llm_aws = TeradataAI(api_type = "aws",
                        model_name = "amazon.titan-embed-text-v2:0")


chat_model_aws = TeradataAI(api_type = "aws",
                            model_name = "anthropic.claude-instant-v1")

vs_instance_dataset = VectorStore.from_datasets(name = "vs_example_from_datasets",
                                                data = input_data,
                                                embedding = llm_aws,
                                                data_columns = "rev_text",
                                                chat_completion_model = chat_model_aws
                                                )

# %%
vs_instance_dataset.status()
# Out:
#                     vs_name status
# 0  vs_example_from_datasets  READY

# %%
vs_instance_dataset.get_details()
# Out:
#                     vs_name     store_type description database_name  sample_size              embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold p_value search_numcluster ef_search initial_centroids_method train_numcluster max_iternum stop_threshold  seed num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_objects           document_objects document_columns document_indexes prompt vector_column        chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status base_url_embeddings base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated metadata_columns base_url_content_safety base_url_topic_control base_url_jailbreak_detection content_safety_model topic_control_model guardrails num_NodesPerGraph onnx_model_table onnx_tokenizer_table onnx_model_id onnx_tokenizer_id onnx_model_column onnx_tokenizer_column onnx_model_id_column onnx_tokenizer_id_column embedding_datatype use_simd base_url_vlm vlm_model maximal_marginal_relevance lambda_multiplier permission
# 0  vs_example_from_datasets  content-based        None           OAF           20  amazon.titan-embed-text-v2:0             1024  COSINE   VECTORDISTANCE     10             None    None              None      None                     None             None        None           None  None     None      None            None            None               None             None            None  ["OAF.amazon_reviews_25"]     ["rev_text"]        ["TD_ID"]   None  vector_index  anthropic.claude-instant-v1            0.2                       None               60                        4096     READY                None                 None            None             None          None            None       None             None               None        None          None                None  2025-08-12 21:17:37.397268+00:00             None                    None                   None                         None                 None                None       None              None             None                 None          None              None              None                  None                 None                     None               None     None         None      None                       None              None      ADMIN

# %%
vs_instance_dataset.destroy()
# Out:
# Vector store vs_example_from_datasets destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### 🛠 Creating a store with the  `add_datasets` method
#
# Users can also create a content based Vector Store by directly using `add_datasets` method

# %%
vs_dataset = VectorStore()

vs_dataset.add_datasets(name = "vs_example_add_datasets",
                        data = "amazon_reviews_25",
                        data_columns = "rev_text",
                        key_columns = ["rev_id", "aid"],
                        embedding = "amazon.titan-embed-text-v2:0"
                        )

# %%
vs_dataset.status()
# Out:
#                    vs_name status
# 0  vs_example_add_datasets  READY

# %%
vs_dataset.get_details()

# %%
vs_dataset.destroy()
# Out:
# Vector store vs_example_add_datasets destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ### 🛠 Instantiating a Content Based Vector Store using `from_texts` method
#
#  **from_texts()**
#    - Creates a new 'content-based' vector store from the input text(s) or list of text(s).
#    - Internally the texts are converted into table and stored to Teradata Vantage.

# %%
# Sample text documents for demonstration
sample_texts = [
    "Teradata Vantage is a modern data platform that unifies data lakes, data warehouses, analytics, and new data sources.",
    "Machine learning models can be deployed directly in Teradata Vantage for in-database analytics and scoring.",
    "Vector databases enable semantic search capabilities by storing and querying high-dimensional embeddings.",
    "Natural language processing with large language models has revolutionized how we interact with data.",
    "SQL is the standard language for managing and querying relational databases across various platforms.",
    "Data science workflows often involve data preparation, model training, validation, and deployment phases.",
    "Cloud computing provides scalable infrastructure for modern data analytics and machine learning workloads.",
    "Real-time analytics enable organizations to make data-driven decisions with minimal latency."
]

print(f"Prepared {len(sample_texts)} text samples for vector store creation")
# Out:
# Prepared 8 text samples for vector store creation

# %%
# Create text-based vector store
try:
    vs_instance_texts = VectorStore.from_texts(name="vs_example_from_texts",
                                               texts=sample_texts,
                                               embedding="amazon.titan-embed-text-v2:0",
                                               )
    
    print("Text-based vector store created successfully!")
    print(f"Vector store name: {vs_instance_texts.name}")
except Exception as e:
    print(f"Error creating text-based vector store: {e}")

# %%
# Check the status of the store.
vs_instance_texts.status()
# Out:
#                  vs_name status
# 0  vs_example_from_texts  READY

# %% [markdown]
# ### Add More Texts to Existing Vector Store

# %%
# Additional texts to add
additional_texts = [
    "Artificial intelligence is transforming industries through automation and intelligent decision-making.",
    "Data governance ensures data quality, security, and compliance across enterprise systems.",
    "Business intelligence tools help organizations visualize and understand their data patterns."
]

# Add texts to existing vector store
try:
    vs_instance_texts.add_texts(texts=additional_texts)
    print(f"Successfully added {len(additional_texts)} additional texts to the vector store")
except Exception as e:
    print(f"Error adding texts: {e}")
# Out:
# Vector store vs_example_from_texts update started.
# Use the 'status()' api to check the status of the operation.
# Successfully added 3 additional texts to the vector store

# %%
# Check if update is complete.
vs_instance_texts.status()
# Out:
#                  vs_name                      status  retry_after
# 0  vs_example_from_texts  UPDATING (PREPARING INPUT)           60

# %% [markdown]
# ### 🔍 Performing Similarity Search, Preparing Response, and Ask
#
# Using the vector store instance created from texts, you can do **similarity search**, prepare a **natural language response**, and ask the updated vector store to retrieve the most relevant information.

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_texts.similarity_search(question=question)

# %%
response.similar_objects
# Out:
#       score DataBaseName                        TableName  TD_ID                                                                                                                   text  index_label
# 0  0.089673          OAF  ml__from_pandas_175535885506159      3            Machine learning models can be deployed directly in Teradata Vantage for in-database analytics and scoring.            2
# 1  0.063534          OAF  ml__from_pandas_175535885506159      5                           Real-time analytics enable organizations to make data-driven decisions with minimal latency.            4
# 2  0.030733          OAF  ml__from_pandas_175535885506159      7  Teradata Vantage is a modern data platform that unifies data lakes, data warehouses, analytics, and new data sources.            5
# 3  0.025891          OAF  ml__from_pandas_175535885506159      8              Vector databases enable semantic search capabilities by storing and querying high-dimensional embeddings.            6
# 4  0.000050          OAF  ml__from_pandas_175535885506159      2              Data science workflows often involve data preparation, model training, validation, and deployment phases.            7
# 5  0.066418          OAF  ml__from_pandas_175535885506159      1             Cloud computing provides scalable infrastructure for modern data analytics and machine learning workloads.            3
# 6  0.090743          OAF  ml__from_pandas_175535885506159      4                   Natural language processing with large language models has revolutionized how we interact with data.            1
# 7  0.249317          OAF  ml__from_pandas_175535885506159      6                  SQL is the standard language for managing and querying relational databases across various platforms.            0

# %%
question = 'Which book are all the reviews talking about?'
response = vs_instance_texts.prepare_response(question=question, similarity_results=response)
print(response)
# Out:
# The given data does not contain any information about a book or book reviews. The text snippets appear to be discussing various topics related to data analytics, machine learning, and database technologies, but there is no mention of a specific book. Therefore, I cannot provide an answer to the question "Which book are all the reviews talking about?" based on the provided information.

# %%
custom_prompt = """List good reviews about the books. Do not assume information. Only provide information that is present in the data.
Format results like this:
review_id: 
Book Title: 
Author: 
Review: 
"""
question="Are there any reviews saying that the books are inspiring?"
response = vs_instance_texts.ask(question=question, prompt=custom_prompt)

# %%
response
# Out:
# 'There are no reviews in the given data that mention the books being inspiring. The data provided contains information about various data-related topics such as SQL, cloud computing, machine learning, and real-time analytics, but does not contain any reviews about books.'

# %%
# Destroy the Vector Store Instance
vs_instance_texts.destroy()
# Out:
# Vector store vs_example_from_texts destroy started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# ## 🔌 Disconnect
# - **Terminate All Active Connections**
#    - This operation terminates all active connections to the vector store database.

# %%
VSManager.disconnect()
# Out:
# Database connection closed.

# %%
remove_context()
# Out:
# True
